# %% [markdown]
# # Done
# * spacy lemmatisation don't remove proper names
#
#
# # To Do
# * bring in bigger sample from other patches
# * nltk to sentence
# * bigram trigram common phrases
#
#
# # Discussion
# * Who is most popular?
# * Common Phrases

# %%
import pandas as pd
import en_core_web_sm
import gensim
import gensim.corpora as corpora
import nltk
import spacy
import sklearn
import gzip
import json

from nltk.corpus import stopwords
stop_words = stopwords.words('english')

from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.models.phrases import Phraser
from pprint import pprint

# Plotting tools
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
#pip list

# %%
pd.options.display.max_rows = 50

df = pd.read_csv('C:\\Users\\Sally\\WTP\\data\\patch69.txt',names=['subtitle'])

#df = pd.read_csv('C:\\Users\\Sally\\WTP\\data\\sample.txt',names=['subtitle'])

# %%
df.head(12)
# Out:
#                                    subtitle
# 0                                       you
# 1                                   [Music]
# 2                                   [Music]
# 3                                   [Music]
# 4                                   [Music]
# 5                                   [Music]
# 6                                   [Music]
# 7                                   [Music]
# 8                                   [Music]
# 9                                   [Music]
# 10  hello good to see there good to see you
# 11       digitally through the screen hello

# %%
df.to_csv('df69.csv')

# %%
data = df.subtitle.values.tolist()

# %%
long_string = df.subtitle.to_string()

# %%
len(long_string)
# Out:
# 77713

# %%
type(long_string)
# Out:
# str

# %%
type(data)
# Out:
# list

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations
        
data_words = list(sent_to_words(data))

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=10, threshold=50000) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)
quadgram = gensim.models.Phrases(trigram[data_words], threshold=100)

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)
quadgram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[22]]])
# Out:
# ['touch', 'pretty', 'good', 'did', 'you', 'have', 'tag']

# %%
#gensim.models.analyze_sentence(sentence, threshold, common_terms, scorer)

# %%
#phrases = gensim.models.Phrases(sentences=data_words,min_count=20, threshold=10, max_vocab_size=100)
phrases = gensim.models.Phrases(sentences=data_words,min_count=50, threshold=10, max_vocab_size=100)
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
for i in phrases.vocab.items():
        print(i)
# Out:
# (b'you', 400)
# (b'to', 262)
# (b'the', 457)
# (b'it', 379)
# (b'just', 1)
# (b'get', 1)
# (b'just_get', 1)
# (b'on', 1)
# (b'get_on', 1)
# (b'our', 1)
# (b'on_our', 1)
# (b'social', 1)
# (b'our_social', 1)
# (b'media', 1)
# (b'social_media', 1)
# (b'we', 1)
# (b'media_we', 1)
# (b'll', 1)
# (b'we_ll', 1)
# (b'let', 1)
# (b'll_let', 1)
# (b'know', 1)
# (b'you_know', 1)
# (b'but', 1)
# (b'know_but', 1)
# (b'in', 1)
# (b'but_in', 1)
# (b'in_the', 1)
# (b'meantime', 1)
# (b'the_meantime', 1)
# (b've', 2)
# (b'meantime_ve', 1)
# (b'been', 2)
# (b've_been', 2)
# (b'dealing', 1)
# (b'josh', 1)
# (b'dealing_josh', 1)
# (b'and', 1)
# (b'josh_and', 1)
# (b'and_ve', 1)
# (b'christian', 1)
# (b'been_christian', 1)
# (b'goodbye', 1)
# (b'music', 3)
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#for ngrams, _ in trigram.vocab.items():
for ngrams, _ in bigram.vocab.items():
    unicode_ngrams = ngrams.decode('utf-8')
    if '_' in unicode_ngrams:
        print(unicode_ngrams)
# Out:
# hello_good
# good_to
# to_see
# see_there
# there_good
# see_you
# digitally_through
# through_the
# the_screen
# screen_hello
# christian_hallowed
# hallowed_deon
# deon_how
# how_are
# are_you
# you_guys
# thought_joshua
# joshua_we
# we_re
# re_gonna
# gonna_get
# get_from
# you_good
# good_target
# target_sounds
# sounds_like
# like_the
# start_of
# of_good
# good_antagonism
# antagonism_how
# how_does
# gutentag_start
# start_uh
# uh_it
# it_starts
# starts_like
# like_josh
# started_it
# it_but
# but_it
# it_doesn
# doesn_end
# end_like
# like_that
# really_good
# good_hug
# hug_it
# it_something
# something_that
# covers_the
# the_whole
# whole_day
# day_yeah
# yeah_really
# also_if
# if_you
# you_see
# see_some
# some_graffiti
# graffiti_and
# and_it
# just_really
# really_really
# really_great
# great_it
# it_good
# touch_pretty
# pretty_good
# good_did
# did_you
# you_have
# have_tag
# when_you
# you_were
# were_younger
# uh_used
# used_to
# to_write
# write_my
# my_initials
# initials_jp
# jp_in
# like_cool
# cool_way
# way_so
# so_would
# would_do
# do_the
# the_and
# then_off
# off_the
# the_back
# back_neck
# neck_of
# of_the
# the_would
# the_curve
# curve_of
# the_ah
# ah_that
# interesting_actually
# actually_fun
# fun_fact
# fact_about
# about_my
# signature_the
# the_in
# in_my
# my_signature
# signature_is
# exactly_or
# or_inspired
# inspired_by
# by_my
# my_mum
# mum_in
# in_her
# signature_surely
# surely_we
# we_all
# all_take
# take_inspiration
# from_our
# our_parents
# parents_signatures
# signatures_right
# right_my
# dad_really
# really_my
# my_my
# my_tag
# tag_at
# at_school
# school_dion
# was_oil
# oil_rig
# rig_it
# it_was
# was_which
# which_which
# which_stands
# for_oxidation
# oxidation_is
# is_loss
# loss_of
# of_electrons
# electrons_and
# reduction_is
# is_gain
# gain_of
# electrons_christian
# surely_you
# were_trying
# trying_not
# not_to
# to_get
# bullied_at
# school_not
# to_increase
# increase_the
# chances_of
# of_that
# that_happening
# happening_was
# was_already
# an_overweight
# overweight_ethnic
# ethnic_but
# but_you
# were_but
# were_am
# am_worried
# worried_like
# like_captain
# captain_of
# something_yes
# yes_did
# you_respect
# respect_it
# it_you
# were_bullied
# bullied_and
# and_respected
# respected_at
# at_the
# the_same
# time_yes
# yes_great
# great_thing
# thing_on
# on_your
# your_tombstone
# the_other
# other_thing
# thing_wanted
# wanted_to
# to_talk
# talk_about
# is_speak
# speak_to
# to_my
# my_mom
# mom_yesterday
# yesterday_and
# and_she
# was_telling
# telling_me
# me_of
# of_an
# an_attempted
# attempted_rooibos
# and_use
# use_the
# the_word
# word_attempted
# attempted_because
# it_it
# it_not
# not_been
# been_going
# going_well
# well_but
# thought_bring
# bring_it
# it_up
# up_you
# you_know
# know_those
# coffee_pods
# pods_and
# and_you
# you_get
# get_your
# your_packet
# packet_on
# with_like
# like_you
# know_in
# in_packet
# packet_or
# whatever_she
# she_bought
# bought_one
# one_of
# of_these
# these_from
# local_supermarket
# supermarket_and
# and_couple
# couple_of
# of_them
# were_like
# like_hard
# hard_and
# and_had
# had_like
# like_broken
# whatever_however
# however_they
# they_break
# break_they
# they_broke
# ground_they
# they_were
# were_rock
# rock_hard
# hard_so
# so_you
# talking_back
# back_it
# was_like
# like_oh
# oh_hey
# hey_these
# these_ones
# ones_are
# are_busted
# busted_and
# and_they
# they_re
# re_guys
# like_well
# well_where
# where_the
# the_rest
# rest_of
# them_it
# well_how
# how_you
# you_meant
# meant_to
# to_know
# know_that
# re_broke
# broke_like
# like_they
# they_don
# don_work
# work_until
# get_to
# to_the
# the_broken
# broken_ones
# ones_right
# right_that
# artwork_yeah
# yeah_yeah
# yeah_and
# and_then
# then_so
# so_that
# that_is
# well_you
# have_to
# to_send
# send_it
# it_back
# back_so
# the_company
# company_so
# so_then
# then_moms
# moms_emailed
# emailed_the
# company_being
# being_ok
# ok_got
# got_this
# this_product
# product_is
# this_thing
# thing_can
# can_you
# you_send
# send_us
# us_photo
# please_ok
# ok_so
# so_keep
# keep_in
# in_mind
# mind_through
# through_all
# all_of
# this_they
# they_cost
# cost_less
# less_than
# than_about
# about_bucks
# how_can
# can_how
# send_photo
# photo_of
# something_feeling
# feeling_rock
# okay_can
# you_can
# you_post
# post_it
# it_out
# out_to
# to_us
# it_just
# just_like
# like_and
# then_the
# the_worst
# and_we
# we_ll
# ll_send
# send_you
# you_voucher
# voucher_shocking
# just_for
# for_something
# something_so
# so_cheap
# cheap_that
# that_could
# have_been
# been_such
# such_great
# great_customer
# experience_they
# they_ve
# ve_just
# just_they
# don_have
# have_name
# name_how
# how_much
# much_was
# was_the
# voucher_worth
# worth_presume
# presume_would
# would_be
# be_the
# cost_of
# of_one
# of_their
# their_products
# products_don
# know_what
# what_don
# don_know
# what_the
# the_voucher
# is_if
# you_go
# go_to
# the_supermarket
# supermarket_go
# go_hey
# have_voucher
# voucher_for
# for_this
# this_specific
# specific_company
# what_josh
# josh_that
# is_not
# not_something
# that_you
# you_would
# would_consider
# consider_big
# big_prize
# thank_you
# you_so
# so_much
# much_we
# ll_get
# get_started
# started_soon
# the_only
# only_reference
# reference_we
# we_might
# might_have
# to_be
# prised_actually
# actually_can
# can_see
# see_in
# in_the
# the_chat
# that_there
# there_had
# had_been
# been_few
# few_references
# references_to
# the_big
# prize_for
# for_those
# those_of
# of_you
# you_who
# aren_aware
# aware_of
# prize_you
# you_ll
# to_stick
# stick_around
# around_right
# right_till
# till_the
# the_end
# because_there
# there_will
# will_be
# be_no
# no_further
# further_mention
# of_said
# said_big
# prize_until
# until_the
# big_reveal
# prize_the
# to_mention
# mention_just
# just_josh
# josh_in
# in_regards
# that_failed
# failed_failed
# failed_rooibos
# rooibos_ordered
# some_gin
# gin_via
# via_damn
# damn_if
# if_he
# he_very
# very_bound
# bound_dan
# murphys_ordered
# ordered_it
# it_and
# and_was
# was_really
# excited_took
# took_ages
# ages_to
# to_arrive
# arrive_open
# open_up
# up_the
# packet_and
# was_bottle
# bottle_of
# of_vodka
# vodka_um
# so_called
# called_them
# them_and
# and_first
# first_message
# then_was
# was_getting
# getting_to
# to_this
# this_back
# back_and
# forth_bother
# bother_this
# this_so
# so_just
# just_call
# call_them
# said_hey
# hey_would
# would_actually
# actually_you
# gonna_do
# do_like
# like_to
# to_keep
# keep_this
# this_vodka
# cuz_it
# good_vodka
# vodka_only
# only_vodka
# vodka_at
# at_home
# and_just
# just_post
# post_and
# post_out
# out_the
# the_the
# gene_that
# that_fine
# fine_now
# now_like
# that_cool
# just_keep
# keep_the
# the_vodka
# vodka_you
# know_to
# to_pay
# pay_for
# it_no
# no_problem
# was_that
# that_they
# they_just
# just_slept
# slept_they
# just_said
# look_we
# we_fucked
# fucked_up
# up_there
# there_the
# the_there
# vodka_and
# ll_post
# post_you
# you_out
# chin_as
# as_well
# well_am
# am_on
# on_streak
# streak_am
# on_an
# absolute_string
# string_did
# photo_no
# no_they
# they_took
# took_your
# your_word
# took_my
# my_word
# word_yeah
# yeah_try
# try_it
# out_it
# ordered_clear
# clear_spirit
# spirit_which
# which_one
# one_it
# was_it
# was_just
# just_it
# was_such
# such_good
# result_what
# what_are
# are_people
# people_saying
# saying_here
# here_in
# the_life
# life_to
# to_just
# just_before
# before_crack
# crack_into
# into_the
# episode_and
# and_kylie
# kylie_saying
# saying_there
# there_big
# prize_shiva
# shiva_you
# disappointing_is
# is_that
# that_the
# prize_has
# been_referenced
# referenced_for
# for_number
# number_of
# of_weeks
# and_got
# got_absolutely
# absolutely_nothing
# nothing_and
# wasn_till
# till_revealed
# revealed_that
# the_prize
# was_big
# big_and
# and_emphasized
# emphasized_how
# how_big
# big_it
# the_people
# people_started
# started_paying
# paying_attention
# attention_can
# just_say
# say_barbara
# barbara_in
# chat_says
# says_oh
# that_reminds
# reminds_me
# of_my
# my_last
# last_year
# year_house
# where_we
# we_had
# had_possum
# possum_scratching
# scratching_in
# wall_and
# and_the
# the_real
# real_estate
# estate_agent
# agent_asked
# asked_us
# us_to
# photo_you
# you_pass
# pass_the
# camera_to
# the_possum
# possum_do
# do_you
# you_mind
# mind_taking
# audio_clip
# clip_jasmine
# jasmine_great
# great_question
# question_how
# does_down
# down_keep
# keep_getting
# getting_free
# free_stuff
# stuff_join
# podcast_jasmine
# jasmine_it
# it_helps
# helps_lot
# lot_it
# the_motivation
# motivation_but
# but_yeah
# yeah_good
# good_luck
# with_everyone
# everyone_with
# with_the
# the_free
# free_prize
# prize_we
# wish_you
# you_all
# all_the
# the_best
# best_of
# of_it
# was_there
# anything_else
# else_we
# we_wanted
# to_cover
# cover_before
# we_cracked
# cracked_into
# the_show
# show_no
# no_think
# re_good
# to_go
# go_so
# so_late
# late_hang
# hang_on
# on_sorry
# josh_if
# you_are
# are_if
# you_re
# re_watching
# watching_this
# you_haven
# haven_subscribed
# subscribed_to
# youtube_channel
# channel_like
# like_this
# this_video
# video_please
# go_do
# do_that
# that_right
# right_now
# now_it
# it_very
# very_easy
# easy_just
# click_the
# the_thumbs
# thumbs_up
# up_button
# button_it
# it_means
# nothing_to
# to_you
# you_but
# little_bit
# bit_to
# us_well
# well_yeah
# yeah_but
# but_if
# have_mouse
# mouse_that
# that_has
# has_limited
# limited_sort
# sort_of
# clicks_left
# left_in
# in_don
# don_click
# click_but
# please_subscribe
# subscribe_to
# to_our
# our_you
# like_human
# human_heart
# actually_if
# you_subscribe
# our_youtube
# channel_right
# now_if
# you_click
# click_on
# subscribe_right
# now_your
# your_name
# name_will
# will_flash
# up_on
# on_the
# screen_that
# that_it
# it_pretty
# pretty_damn
# good_incentive
# incentive_rather
# rather_than
# than_doing
# doing_it
# it_from
# the_goodness
# goodness_of
# of_your
# your_heart
# heart_your
# will_flush
# flush_up
# thing_is
# that_if
# that_anyone
# anyone_is
# is_like
# like_bit
# bit_down
# down_at
# the_moment
# moment_or
# or_needs
# needs_bit
# bit_of
# of_cheer
# cheer_up
# send_them
# them_the
# the_link
# link_to
# live_stream
# stream_and
# and_and
# and_hopefully
# hopefully_you
# they_can
# can_come
# come_along
# along_and
# and_find
# find_patrick
# patrick_as
# but_for
# for_now
# now_let
# let_start
# start_the
# should_use
# best_space
# space_under
# under_my
# my_beer
# if_questions
# questions_like
# this_have
# have_crossed
# crossed_your
# mind_what
# what_keep
# keep_doing
# doing_is
# is_keep
# write_this
# this_out
# out_and
# then_put
# put_it
# it_in
# in_tiny
# lettering_and
# and_can
# can_could
# could_it
# it_be
# be_front
# row_with
# the_box
# box_so
# so_sorry
# sorry_let
# let_do
# this_again
# should_best
# best_use
# the_space
# bed_if
# your_mind
# mind_then
# then_you
# re_in
# in_good
# good_company
# today_we
# ll_be
# be_taking
# taking_closer
# closer_look
# look_at
# some_of
# the_daily
# daily_habits
# habits_and
# and_social
# conventions_that
# that_make
# make_up
# the_monotony
# monotony_of
# life_let
# let_try
# try_to
# to_move
# move_the
# the_glory
# glory_residue
# left_my
# my_sticker
# sticker_residue
# residue_my
# my_bedroom
# bedroom_with
# now_before
# before_before
# before_we
# we_get
# started_just
# want_to
# to_let
# let_you
# guys_know
# know_this
# this_will
# of_bumper
# bumper_episode
# episode_because
# because_we
# taking_bit
# of_break
# break_we
# ll_explain
# bit_more
# more_at
# end_of
# show_but
# but_just
# know_ve
# ve_got
# got_big
# big_episode
# episode_plan
# plan_for
# for_you
# guys_cuz
# cuz_we
# we_will
# be_stopping
# stopping_patrick
# patrick_for
# little_while
# while_but
# but_um
# um_yeah
# yeah_more
# more_and
# and_more
# show_and
# and_now
# now_for
# for_actually
# started_bit
# it_is
# of_bone
# bone_to
# to_pick
# pick_with
# with_you
# you_christian
# you_um
# um_the
# the_way
# way_you
# you_put
# put_the
# the_tea
# towels_away
# away_so
# so_dion
# dion_you
# have_tea
# tea_towels
# right_you
# re_drying
# drying_dishes
# dishes_whatever
# where_would
# would_you
# you_traditionally
# traditionally_place
# tea_towel
# towel_once
# once_you
# you_ve
# ve_finished
# finished_right
# what_is
# is_it
# it_normally
# normally_it
# it_like
# like_used
# used_and
# currently_in
# in_use
# use_tea
# towel_currently
# news_tea
# towel_always
# always_lives
# lives_on
# little_rack
# rack_but
# but_we
# re_the
# the_oven
# oven_yeah
# yeah_the
# oven_lay
# lay_over
# over_the
# oven_the
# okay_so
# so_these
# these_are
# are_these
# are_the
# the_places
# they_have
# have_god
# god_sits
# sits_christian
# christian_has
# moved_us
# oh_god
# god_leg
# leg_over
# over_all
# the_wet
# wet_dishes
# dishes_on
# the_train
# train_wreck
# wreck_not
# not_huge
# huge_issue
# issue_laying
# the_stovetop
# stovetop_hanging
# hanging_half
# half_down
# down_over
# in_front
# front_of
# oven_and
# then_flat
# flat_out
# just_on
# the_kitchen
# kitchen_fully
# fully_laid
# laid_out
# out_on
# kitchen_bench
# bench_and
# then_continually
# used_laid
# there_been
# been_crumbs
# crumbs_thrown
# thrown_on
# on_it
# it_there
# been_chopping
# chopping_boards
# boards_put
# put_on
# it_all
# all_kinds
# of_different
# different_things
# things_and
# then_what
# happens_you
# get_filthy
# filthy_tea
# christian_explain
# explain_yourself
# alright_josh
# josh_to
# to_start
# start_with
# with_sick
# sick_of
# people_telling
# me_how
# how_should
# should_be
# be_using
# towels_they
# they_do
# do_not
# not_have
# have_discreet
# purpose_that
# to_use
# use_them
# them_in
# particular_way
# way_or
# or_is
# is_giveaway
# giveaway_there
# but_think
# think_you
# you_mean
# mean_what
# the_giveaway
# to_wipe
# wipe_up
# up_shirley
# shirley_what
# it_what
# is_tea
# towel_what
# the_purpose
# purpose_of
# towel_okay
# okay_nichelle
# nichelle_tea
# be_used
# used_pretty
# pretty_much
# much_exclusively
# for_drying
# drying_wet
# dishes_drying
# wet_clean
# it_josh
# josh_drying
# clean_dishes
# okay_don
# don_mind
# mind_it
# and_maybe
# maybe_little
# of_dry
# dry_your
# your_fingers
# fingers_but
# but_primarily
# its_primary
# primary_function
# function_is
# is_to
# to_dry
# dry_wet
# dishes_okay
# so_there
# there_there
# there_are
# are_two
# separate_issues
# issues_here
# here_the
# the_first
# first_is
# obviously_the
# the_issue
# issue_that
# ve_pointed
# out_with
# with_where
# where_leave
# leave_the
# to_leave
# towel_over
# the_dishes
# dishes_after
# after_they
# ve_been
# been_after
# after_that
# when_they
# re_drip
# drip_drying
# drying_because
# because_that
# allows_for
# for_circulation
# circulation_of
# of_air
# air_to
# to_hit
# wait_second
# second_josh
# josh_there
# there_two
# two_there
# two_reasons
# reasons_with
# with_that
# that_because
# because_don
# to_fold
# fold_it
# it_over
# over_itself
# itself_and
# and_hang
# hang_it
# oven_where
# where_it
# it_touching
# touching_itself
# it_gonna
# gonna_take
# take_longer
# longer_to
# dry_so
# to_make
# make_sure
# sure_that
# is_one
# one_sheet
# has_as
# as_much
# much_surface
# surface_area
# area_exposed
# exposed_to
# the_air
# air_that
# it_will
# will_dry
# dry_faster
# faster_but
# but_also
# it_doubles
# doubles_up
# up_as
# as_hiding
# hiding_the
# dishes_that
# are_drying
# drying_okay
# okay_josh
# josh_mean
# mean_like
# would_love
# love_to
# to_agree
# agree_with
# you_at
# at_this
# this_in
# this_situation
# situation_don
# know_why
# why_but
# absolutely_love
# love_when
# when_christian
# christian_puts
# over_dishes
# dishes_it
# like_home
# home_that
# wish_would
# would_have
# have_grown
# grown_up
# up_in
# in_day
# see_that
# is_good
# good_tag
# tag_don
# what_it
# just_know
# that_sure
# christian_you
# you_observe
# observe_your
# your_mom
# mom_doing
# sure_we
# we_ve
# ve_probably
# probably_talked
# talked_about
# in_multiple
# multiple_patches
# patches_but
# for_me
# think_that
# the_bit
# bit_that
# that_don
# don_get
# that_like
# like_want
# to_find
# find_out
# inherent_purpose
# the_tail
# tail_why
# why_is
# going_to
# see_tail
# why_isn
# isn_the
# the_tower
# when_go
# the_bathroom
# bathroom_why
# isn_it
# called_body
# body_towel
# towel_or
# or_shower
# shower_towel
# towel_why
# just_why
# why_why
# why_we
# re_just
# just_using
# generic_towel
# well_they
# do_have
# have_hand
# hand_towels
# towels_yeah
# that_true
# true_so
# so_which
# which_is
# is_small
# small_which
# smaller_towels
# towels_for
# for_your
# your_hand
# hand_that
# that_makes
# sense_samantha
# samantha_in
# the_youtube
# youtube_chat
# chat_has
# suggested_that
# that_tea
# towel_represents
# tea_is
# is_in
# in_dinner
# dinner_so
# so_it
# like_dinner
# towel_think
# towel_should
# flexible_it
# it_should
# be_able
# able_to
# to_clean
# clean_up
# spills_and
# the_reason
# reason_josh
# that_put
# beneath_chopping
# chopping_board
# board_as
# as_as
# chopping_on
# the_board
# board_is
# is_so
# it_can
# capture_the
# the_spills
# spills_over
# the_chopping
# board_excel
# excel_when
# when_could
# could_have
# have_given
# given_you
# an_out
# out_then
# then_if
# you_said
# said_the
# the_correct
# answer_to
# to_that
# reason_put
# put_tea
# towel_under
# under_the
# stop_it
# it_sliding
# sliding_around
# around_would
# have_even
# thought_yes
# yes_it
# it_does
# does_that
# that_as
# to_catch
# catch_spills
# and_stuff
# stuff_because
# got_clean
# clean_dry
# dry_wipe
# wipe_surface
# there_that
# you_could
# could_just
# just_wipe
# wipe_it
# it_with
# chuck_christian
# christian_no
# no_josh
# josh_chuck
# chuck_okay
# chuck_are
# are_disgusting
# disgusting_wet
# wet_things
# of_cleaning
# cleaning_things
# things_up
# dryness_of
# towel_is
# is_purely
# purely_for
# clean_things
# things_you
# you_shouldn
# shouldn_be
# be_getting
# tail_dirty
# dirty_why
# why_not
# not_what
# what_do
# you_think
# the_brand
# brand_chuck
# chuck_came
# came_from
# from_like
# like_is
# that_after
# after_is
# after_someone
# named_charlie
# charlie_or
# just_sucks
# sucks_it
# just_chuck
# chuck_it
# over_there
# there_sorry
# what_chuck
# over_chuck
# think_there
# there_nothing
# nothing_wrong
# wrong_with
# getting_tea
# towel_dirty
# dirty_because
# because_it
# goes_in
# the_wash
# wash_the
# the_point
# point_is
# to_have
# and_don
# know_whether
# whether_this
# this_is
# is_because
# my_grandfather
# grandfather_owned
# owned_like
# like_an
# an_italian
# manchester_store
# store_that
# that_sold
# sold_we
# endless_numbers
# numbers_of
# of_details
# details_girls
# girls_covered
# in_plastic
# plastic_they
# the_good
# good_tea
# for_visitors
# visitors_so
# so_josh
# josh_where
# you_like
# like_christian
# christian_to
# to_put
# these_where
# where_wait
# wait_what
# are_his
# his_options
# does_he
# he_have
# have_few
# few_options
# options_think
# think_over
# the_over
# the_arm
# arm_of
# the_ovens
# ovens_great
# and_over
# the_top
# top_of
# dishes_less
# worried_about
# my_main
# main_concern
# concern_is
# being_used
# up_and
# and_to
# get_dirty
# dirty_in
# kitchen_don
# you_should
# getting_dirty
# don_think
# think_it
# used_in
# in_tidy
# tidy_up
# fashion_think
# that_what
# the_tux
# tux_is
# can_squeeze
# squeeze_out
# out_of
# chucks_and
# it_practically
# practically_dry
# dry_it
# it_an
# interesting_point
# point_christian
# christian_because
# ultimately_if
# re_using
# using_it
# it_for
# cleaning_it
# it_contaminates
# contaminates_when
# when_josh
# josh_is
# doing_the
# dishes_and
# know_drying
# drying_the
# contaminates_that
# that_process
# process_what
# what_does
# does_have
# have_is
# is_josh
# josh_how
# how_do
# you_expect
# josh_dries
# dries_dishes
# dishes_now
# now_we
# we_don
# don_dry
# dry_the
# dishes_though
# though_why
# why_drive
# drive_it
# it_we
# we_dry
# the_rack
# rack_they
# do_big
# big_pot
# that_doesn
# doesn_come
# come_on
# on_there
# there_you
# you_trying
# right_away
# right_with
# towel_might
# might_be
# the_so
# keep_it
# it_beneath
# beneath_the
# board_for
# spills_talking
# talking_about
# about_capsicum
# seeds_talking
# about_off
# off_cuts
# cuts_of
# onion_yep
# yep_and
# then_when
# you_take
# take_off
# board_you
# you_pick
# pick_up
# four_corners
# corners_together
# together_and
# you_you
# run_away
# away_from
# from_home
# home_so
# so_the
# other_day
# after_about
# about_good
# good_long
# long_years
# years_and
# hassling_of
# my_girlfriend
# girlfriend_decided
# decided_to
# finally_clean
# clean_underneath
# underneath_my
# my_bed
# bed_so
# so_what
# ve_basically
# basically_done
# done_is
# is_since
# since_up
# up_since
# was_kid
# kid_have
# have_moved
# moved_the
# the_contents
# of_like
# like_basically
# basically_it
# just_all
# all_this
# electrical_shit
# shit_like
# like_cables
# cables_and
# and_all
# all_electrical
# electrical_stuff
# stuff_that
# that_just
# just_didn
# get_didn
# didn_want
# get_rid
# rid_of
# and_ve
# ve_moved
# moved_it
# from_house
# house_to
# to_house
# and_finally
# finally_it
# it_landed
# landed_in
# the_house
# that_live
# live_in
# in_now
# now_underneath
# bed_and
# finally_like
# like_sorted
# sorted_through
# through_it
# really_didn
# didn_take
# take_long
# long_time
# time_but
# but_my
# god_there
# there_was
# was_some
# some_stuff
# stuff_there
# like_why
# why_have
# have_kept
# kept_this
# this_for
# such_long
# time_so
# it_combination
# of_cables
# and_hard
# hard_drives
# drives_and
# and_pits
# basically_all
# all_these
# these_electronic
# electronic_things
# that_were
# were_stored
# stored_in
# in_three
# three_big
# big_plastic
# boxes_and
# and_on
# on_side
# side_note
# note_my
# had_this
# this_genius
# genius_idea
# idea_so
# know_the
# fishing_tackle
# tackle_boxes
# boxes_you
# the_clear
# plastic_boxes
# boxes_with
# with_all
# the_dividers
# dividers_in
# like_hey
# hey_let
# let_buy
# buy_these
# big_ones
# ones_and
# just_put
# put_all
# your_things
# in_there
# there_we
# we_can
# can_sort
# sort_it
# out_so
# so_anyway
# ended_up
# up_getting
# getting_it
# but_really
# really_want
# to_ask
# ask_you
# to_like
# like_get
# get_patrick
# patrick_is
# really_reflect
# reflect_today
# today_on
# on_um
# have_under
# under_your
# your_bed
# bed_doesn
# need_to
# be_there
# there_and
# chuck_chuck
# the_fucking
# fucking_stuff
# stuff_out
# the_most
# most_what
# post_the
# most_bizarre
# bizarre_thing
# thing_that
# ve_always
# always_found
# found_that
# that_lives
# lives_under
# bed_are
# are_rays
# rays_because
# absolutely_nowhere
# nowhere_for
# for_anyone
# anyone_to
# to_store
# rays_and
# and_there
# there_absolutely
# absolutely_no
# no_reason
# for_us
# have_them
# them_don
# don_give
# give_us
# us_rays
# of_our
# our_appointment
# appointment_what
# you_want
# want_us
# to_do
# do_with
# with_them
# digitized_why
# why_aren
# aren_extra
# extra_why
# why_they
# giving_you
# you_hardcopy
# hardcopy_rays
# rays_to
# to_give
# give_you
# an_one
# your_bloody
# bloody_legs
# legs_they
# they_like
# it_too
# too_big
# big_why
# story_money
# money_your
# bed_sure
# sure_it
# like_shirt
# flat_ll
# ll_tell
# tell_you
# you_why
# why_where
# where_else
# else_is
# is_flat
# enough_and
# and_big
# big_enough
# enough_in
# in_your
# your_house
# on_how
# big_rays
# rays_are
# are_they
# they_actually
# the_io
# io_was
# was_poster
# poster_size
# size_once
# once_they
# they_on
# on_my
# ray_you
# have_you
# you_probably
# probably_have
# have_it
# it_cuz
# you_did
# did_something
# something_quite
# quite_bad
# bad_to
# to_your
# leg_when
# younger_didn
# didn_you
# probably_got
# this_probably
# probably_lot
# steeped_in
# in_these
# these_rays
# rays_you
# them_because
# because_reckon
# someday_you
# think_to
# to_yourself
# yourself_hey
# might_need
# need_this
# this_if
# if_something
# something_happens
# they_might
# go_back
# and_have
# at_them
# them_well
# well_that
# is_the
# the_thing
# have_no
# no_that
# that_why
# why_don
# give_them
# them_to
# me_because
# whether_they
# still_relevant
# relevant_after
# after_two
# two_years
# years_is
# is_my
# my_leg
# gonna_look
# look_the
# same_under
# under_ray
# ray_vision
# my_god
# god_you
# ve_changed
# got_enough
# enough_got
# got_it
# it_if
# you_don
# don_want
# keep_hold
# hold_of
# an_ray
# ray_just
# wondering_is
# is_an
# ray_regarded
# regarded_as
# soft_plastic
# plastic_the
# only_the
# only_thing
# that_know
# know_how
# how_to
# to_read
# read_on
# the_ray
# ray_is
# much_poo
# poo_you
# have_in
# your_in
# colon_yeah
# yeah_that
# it_that
# it_because
# once_my
# my_dad
# dad_had
# had_an
# ray_and
# and_he
# he_was
# oh_the
# the_doctor
# doctor_told
# told_me
# me_this
# is_all
# all_poo
# like_great
# great_okay
# that_all
# all_look
# look_for
# love_this
# this_one
# the_one
# favorite_things
# things_are
# are_doing
# doing_these
# these_um
# um_these
# podcast_now
# now_is
# youtube_live
# live_streams
# just_got
# got_jules
# jules_just
# just_says
# are_digitized
# digitized_just
# just_love
# love_that
# things_can
# can_get
# get_cleared
# cleared_up
# up_so
# so_quickly
# quickly_on
# the_spot
# spot_when
# when_said
# said_go
# go_get
# get_them
# christian_eric
# eric_and
# and_if
# get_are
# they_under
# bed_now
# now_cuz
# cuz_you
# it_now
# now_because
# because_they
# they_because
# because_ve
# moved_into
# into_this
# this_place
# place_and
# and_decided
# decided_you
# those_rays
# rays_they
# re_going
# going_into
# bin_ray
# ray_it
# is_weird
# weird_thing
# them_like
# like_clearly
# clearly_the
# the_rays
# not_for
# you_yet
# yet_they
# they_go
# to_their
# their_take
# this_as
# as_somebody
# somebody_knows
# knows_how
# read_it
# yeah_alright
# alright_could
# could_you
# you_decide
# decide_to
# to_them
# no_yeah
# yeah_you
# got_to
# do_it
# courier_actually
# actually_just
# just_gonna
# gonna_try
# try_one
# thing_out
# with_our
# our_producer
# producer_producer
# producer_if
# just_um
# um_get
# your_finger
# finger_on
# buzzer_christian
# christian_just
# said_rays
# the_bin
# bin_but
# me_in
# in_terms
# terms_of
# beard_it
# it_largely
# largely_have
# have_very
# very_low
# low_bed
# so_not
# not_fitting
# fitting_tags
# tags_or
# or_boxes
# boxes_under
# got_bear
# bear_let
# let_say
# say_know
# know_four
# four_inches
# inches_or
# or_something
# so_all
# all_that
# that_have
# is_pretty
# much_old
# show_posters
# posters_when
# when_we
# ve_printed
# printed_far
# far_too
# many_posters
# posters_or
# or_festival
# festival_gets
# gets_canceled
# yeah_every
# every_don
# don_and
# got_all
# posters_so
# so_lot
# lot_of
# of_old
# old_show
# show_posts
# posts_lot
# old_flyers
# flyers_that
# that_about
# about_it
# it_used
# much_mainly
# mainly_been
# been_that
# the_last
# last_ah
# ah_geez
# geez_or
# something_because
# all_it
# all_started
# started_when
# first_moved
# moved_out
# and_lazily
# lazily_didn
# didn_and
# don_often
# often_talk
# about_his
# his_podcast
# before_had
# had_the
# the_mattress
# mattress_didn
# didn_have
# bed_frame
# frame_at
# the_time
# time_and
# and_so
# so_was
# was_living
# living_mattress
# mattress_on
# the_floor
# floor_like
# some_like
# like_at
# at_it
# was_here
# here_was
# is_hell
# hell_cannot
# cannot_cannot
# cannot_maintain
# maintain_this
# it_disgusting
# disgusting_it
# it_disgraceful
# week_goes
# goes_by
# by_and
# not_too
# too_bad
# bad_it
# bad_anyway
# anyway_so
# so_couldn
# couldn_keep
# anything_under
# there_all
# this_stuff
# that_was
# was_used
# to_keeping
# bed_had
# had_to
# it_or
# it_on
# on_shelf
# shelf_somewhere
# somewhere_so
# so_think
# that_that
# that_really
# really_set
# set_tone
# tone_for
# for_not
# not_not
# really_keeping
# keeping_lot
# of_stuff
# stuff_under
# bed_thought
# thought_you
# gonna_tell
# tell_us
# us_how
# uncomfortable_it
# was_still
# still_trying
# trying_to
# sleep_with
# floor_and
# have_things
# things_under
# the_bed
# bed_dig
# dig_bit
# deeper_wanted
# your_your
# your_view
# view_on
# is_under
# bed_storage
# storage_good
# good_for
# for_mean
# as_some
# some_would
# would_say
# say_absolutely
# nothing_but
# what_what
# what_up
# up_what
# what_um
# um_but
# but_what
# it_actually
# actually_good
# for_like
# like_what
# should_you
# you_be
# be_storing
# storing_under
# under_then
# then_because
# recently_ve
# been_looking
# looking_at
# at_bed
# bed_frames
# have_like
# like_big
# big_gas
# gas_lifting
# lifting_on
# you_lift
# lift_up
# whole_mattress
# mattress_and
# have_this
# this_amazing
# amazing_storage
# storage_underneath
# feel_like
# like_it
# storage_is
# lost_space
# space_and
# well_we
# we_live
# in_smaller
# smaller_apartments
# guess_in
# in_in
# in_melbourne
# melbourne_um
# yeah_we
# we_got
# maximize_space
# space_so
# the_idea
# idea_what
# what_fine
# fine_linen
# linen_think
# think_oh
# that_great
# great_idea
# idea_honest
# honest_if
# you_had
# had_if
# had_um
# um_dedicated
# dedicated_storage
# storage_under
# bed_like
# was_built
# built_into
# the_frame
# itself_then
# you_may
# may_as
# well_utilize
# utilize_it
# ve_think
# think_bags
# bags_backpacks
# backpacks_large
# large_bags
# shoes_think
# think_she
# she_very
# very_shoes
# shoes_it
# good_one
# one_linen
# linen_towels
# towels_are
# are_okay
# okay_but
# like_feel
# want_something
# like_under
# bed_is
# permanent_storage
# storage_like
# like_camping
# camping_equipment
# don_use
# use_that
# that_often
# that_shame
# shame_attend
# attend_give
# give_your
# your_fishing
# rod_under
# bed_my
# my_parents
# parents_place
# sleep_sleep
# sleep_fishing
# fishing_in
# the_middle
# middle_what
# think_anything
# anything_like
# what_you
# mean_don
# don_you
# re_getting
# long_term
# term_storage
# storage_think
# think_think
# it_so
# so_long
# term_though
# though_that
# never_really
# really_getting
# it_think
# the_stuff
# that_ends
# ends_up
# up_under
# it_stuff
# ve_accumulated
# accumulated_over
# time_maybe
# maybe_it
# it_souvenirs
# souvenirs_mementoes
# mementoes_and
# it_really
# really_not
# not_getting
# getting_used
# used_like
# like_ever
# well_christian
# christian_do
# you_own
# own_and
# and_operate
# your_own
# own_self
# self_storage
# storage_business
# business_do
# understand_the
# the_concept
# concept_of
# that_sort
# storage_because
# it_seems
# seems_nuts
# nuts_that
# got_excess
# excess_stuff
# stuff_and
# go_you
# what_gonna
# look_into
# enough_to
# pay_someone
# someone_monthly
# monthly_don
# put_you
# of_business
# business_but
# but_pay
# someone_please
# please_stop
# stop_please
# please_think
# really_straight
# straight_that
# that_idea
# idea_of
# strange_do
# like_just
# just_if
# too_much
# much_stuff
# stuff_clear
# clear_it
# out_but
# but_maybe
# that_naive
# naive_maybe
# maybe_maybe
# maybe_not
# not_you
# don_slow
# slow_second
# second_dumb
# dumb_stuff
# out_exactly
# is_we
# re_lucky
# have_somewhere
# somewhere_to
# to_dump
# dump_our
# stuff_but
# but_things
# things_accumulate
# accumulate_and
# don_once
# ve_invested
# invested_money
# money_into
# buying_that
# that_thing
# thing_even
# even_if
# re_only
# one_more
# more_time
# time_in
# the_future
# future_it
# make_sense
# sense_to
# to_throw
# throw_it
# out_no
# no_what
# what_did
# know_it
# really_weird
# weird_though
# christian_when
# when_went
# went_last
# last_last
# last_time
# went_to
# house_and
# like_your
# folks_house
# house_went
# the_garage
# garage_there
# stuff_in
# there_it
# it_hasn
# hasn_been
# been_so
# so_don
# don_like
# like_lots
# and_lots
# lots_of
# was_thinking
# thinking_to
# myself_that
# is_kind
# kind_of
# like_if
# if_people
# people_at
# your_self
# business_found
# found_out
# guys_didn
# didn_know
# storage_it
# it_kind
# like_psychiatrist
# psychiatrist_son
# son_being
# being_total
# nutjob_and
# re_kind
# what_hang
# on_work
# work_mate
# mate_we
# re_leasing
# leasing_out
# garage_so
# so_previously
# previously_as
# as_guess
# guess_it
# of_spin
# spin_off
# off_of
# the_rooibos
# challenge_can
# can_believe
# believe_we
# we_haven
# used_that
# that_word
# word_internation
# internation_high
# high_team
# we_have
# have_developed
# developed_it
# it_of
# of_concept
# concept_where
# we_write
# write_into
# into_either
# either_company
# company_or
# person_or
# or_an
# an_inanimate
# inanimate_object
# object_and
# start_by
# by_saying
# saying_hi
# hi_teaming
# teaming_and
# and_this
# this_week
# gonna_kick
# kick_it
# it_off
# off_with
# with_hi
# hi_team
# team_hi
# glasses_industry
# industry_have
# have_considered
# everything_in
# the_world
# world_and
# and_cannot
# wrap_my
# my_head
# head_around
# around_why
# why_glasses
# glasses_frames
# are_so
# so_expensive
# expensive_custom
# custom_lenses
# lenses_get
# get_but
# frames_are
# are_literally
# literally_just
# just_plastic
# plastic_yes
# they_call
# them_acetate
# acetate_but
# but_acetate
# acetate_is
# plastic_please
# stop_making
# making_me
# me_feel
# like_buying
# buying_cheap
# cheap_shocking
# shocking_plastic
# for_it
# an_awful
# awful_feeling
# feeling_twenty
# cricket_regards
# regards_okay
# okay_guess
# guess_ll
# my_letter
# letter_hi
# hi_small
# small_tear
# tear_in
# my_movie
# ticket_team
# team_you
# are_completely
# unnecessary_part
# part_of
# the_transaction
# between_myself
# myself_and
# the_employee
# employee_who
# who_lets
# me_into
# the_cinema
# cinema_surround
# surround_sound
# regards_christian
# christian_sit
# sit_off
# off_might
# might_as
# cyan_ink
# ink_team
# team_why
# it_always
# always_you
# runs_out
# out_fed
# fed_up
# up_with
# with_not
# not_being
# being_able
# to_print
# print_because
# because_of
# don_even
# print_in
# in_color
# color_ever
# however_shoutouts
# shoutouts_to
# to_magenta
# magenta_and
# and_yellow
# volvo_regards
# christian_sure
# sure_josh
# josh_dion
# problem_no
# problem_sorry
# sorry_thought
# we_were
# were_going
# going_thought
# thought_we
# we_could
# could_be
# about_me
# me_watching
# watching_trains
# trains_run
# straight_to
# guys_josh
# josh_you
# can_do
# do_any
# problem_yeah
# yeah_so
# so_problem
# ah_okay
# so_christian
# christian_tea
# tea_on
# on_problem
# leaving_the
# the_fridge
# fridge_door
# door_open
# open_as
# as_you
# you_walk
# and_forth
# forth_to
# kitchen_christian
# problem_they
# problem_yes
# yes_josh
# josh_think
# re_think
# think_big
# big_problem
# problem_leaving
# open_when
# going_back
# back_think
# every_time
# time_you
# you_leave
# leave_and
# and_walk
# walk_away
# fridge_you
# you_need
# be_closing
# closing_the
# fridge_why
# why_what
# the_reasoning
# reasoning_for
# just_because
# it_shit
# shit_rule
# rule_you
# come_up
# with_no
# no_because
# because_what
# fridges_job
# job_to
# the_interior
# interior_of
# fridge_cool
# cool_ryan
# ryan_and
# it_regulates
# regulates_that
# temperature_what
# is_your
# your_job
# job_what
# what_your
# to_shut
# shut_the
# the_fuck
# fuck_up
# up_leave
# so_we
# re_not
# not_letting
# letting_all
# the_cold
# air_escape
# escape_and
# not_having
# having_to
# to_work
# harder_to
# cool_that
# why_helping
# helping_it
# it_do
# do_its
# its_job
# just_think
# that_these
# these_fridges
# fridges_we
# what_goes
# goes_into
# into_them
# them_they
# re_sure
# sure_they
# re_bloody
# bloody_heavy
# heavy_they
# ask_fridges
# fridges_this
# first_point
# point_to
# make_fridges
# fridges_are
# so_heavy
# heavy_you
# you_ever
# ever_tried
# move_big
# big_fridge
# fridge_they
# they_are
# are_impossible
# move_so
# point_but
# are_made
# made_they
# they_blair
# blair_makes
# makes_premium
# quality_and
# and_josh
# mean_josh
# josh_do
# have_problem
# problem_if
# to_antarctica
# antarctica_getting
# getting_out
# the_car
# car_and
# know_heating
# heating_up
# up_heating
# the_snowcaps
# snowcaps_like
# problem_here
# here_sure
# sure_he
# he_just
# gonna_like
# gonna_be
# be_if
# if_had
# had_heater
# heater_box
# and_lived
# lived_in
# in_antarctica
# antarctica_and
# and_opened
# the_heater
# box_and
# it_started
# started_blowing
# heater_arctica
# arctica_josh
# so_if
# if_am
# am_if
# if_going
# something_if
# if_gonna
# gonna_put
# put_things
# things_back
# fridge_right
# right_yeah
# yeah_if
# if_taking
# cost_benefit
# benefit_analysis
# analysis_of
# of_this
# this_it
# is_more
# an_inconvenience
# inconvenience_to
# have_the
# the_door
# constantly_shut
# shut_and
# and_me
# me_with
# with_my
# my_arms
# arms_full
# to_open
# open_it
# put_something
# in_rather
# than_just
# just_leaving
# leaving_it
# it_open
# open_for
# the_seconds
# seconds_that
# that_gonna
# be_think
# to_say
# say_how
# how_quickly
# quickly_do
# things_warm
# warm_up
# up_okay
# all_ll
# ll_give
# you_if
# know_say
# say_say
# re_putting
# putting_things
# back_in
# right_if
# re_if
# know_exactly
# exactly_what
# re_grabbing
# grabbing_on
# on_each
# each_trip
# trip_and
# not_thinking
# thinking_and
# not_walking
# around_it
# like_gonna
# get_this
# thing_this
# thing_and
# straight_back
# forth_ll
# ll_allow
# allow_it
# if_there
# there_is
# go_put
# put_stuff
# leave_it
# open_wash
# wash_give
# us_the
# the_proper
# scenario_that
# that_would
# would_happen
# happen_when
# when_it
# going_in
# in_on
# the_bench
# bench_right
# made_sanger
# sanger_you
# you_got
# got_your
# your_milk
# milk_for
# glass_of
# of_milk
# your_butter
# butter_out
# out_you
# mayo_you
# got_bunch
# bunch_of
# of_veggies
# veggies_right
# you_grab
# grab_the
# the_milk
# milk_you
# walk_over
# you_open
# open_the
# fridge_that
# that_goes
# in_would
# would_close
# close_it
# it_again
# again_but
# back_you
# grabbing_the
# butter_you
# grabbing_capsicum
# capsicum_you
# back_to
# fridge_the
# the_capsicum
# come_from
# from_what
# you_worried
# though_josh
# josh_like
# the_concern
# concern_using
# using_up
# up_more
# more_energy
# energy_you
# shouldn_just
# just_leave
# fridge_ajar
# ajar_not
# first_time
# time_josh
# josh_has
# has_brought
# brought_this
# this_up
# christian_over
# over_using
# using_energy
# energy_with
# heat_on
# on_his
# his_feet
# creet_and
# josh_have
# you_observed
# christian_leaving
# fridge_open
# during_summer
# summer_exclusively
# exclusively_jesus
# jesus_hot
# today_ll
# ll_open
# fridge_aah
# aah_how
# how_else
# you_gonna
# get_cold
# fridge_risk
# risk_are
# are_because
# because_realized
# will_will
# will_really
# really_heavily
# heavily_err
# err_on
# side_of
# of_fridge
# fridge_close
# close_as
# much_as
# as_possible
# feel_guilty
# guilty_when
# when_peek
# peek_in
# fridge_for
# for_too
# too_long
# long_if
# if_might
# might_looking
# for_some
# some_white
# white_know
# what_want
# want_my
# my_is
# it_the
# understand_is
# is_how
# can_take
# take_such
# firm_line
# line_on
# on_this
# this_without
# without_having
# having_the
# concern_of
# of_being
# being_worried
# about_every
# other_part
# part_in
# your_life
# life_that
# conserving_energy
# energy_yeah
# good_point
# probably_better
# better_to
# just_take
# take_what
# get_right
# right_so
# if_that
# little_thing
# that_want
# do_to
# put_my
# my_green
# green_step
# step_on
# the_globe
# did_recently
# recently_though
# decided_for
# for_no
# reason_every
# time_ve
# always_bought
# bought_like
# if_it
# it_black
# black_point
# my_life
# life_ve
# always_had
# had_shit
# shit_fridge
# buy_new
# new_one
# one_because
# because_you
# re_nut
# nut_job
# you_buy
# new_fridge
# fridge_or
# or_you
# you_cut
# cut_over
# new_car
# car_but
# but_said
# said_look
# look_gonna
# gonna_buy
# one_for
# for_for
# for_bucks
# bucks_or
# something_and
# bought_it
# and_upsized
# upsized_and
# now_have
# an_oversized
# oversized_fridge
# fridge_which
# thing_in
# world_it
# not_even
# even_the
# best_thing
# thing_it
# amount_of
# of_freezer
# freezer_space
# space_can
# can_like
# like_can
# go_out
# out_could
# could_go
# to_to
# the_to
# pristine_waters
# waters_of
# of_tasmania
# tasmania_and
# and_could
# catch_as
# as_many
# many_salmon
# salmon_as
# as_like
# could_freeze
# freeze_them
# them_all
# all_put
# put_them
# freezer_and
# they_be
# be_totally
# totally_fine
# they_keep
# the_six
# six_months
# months_so
# so_my
# question_to
# you_too
# too_though
# though_how
# how_long
# long_are
# you_comfortable
# comfortable_you
# think_the
# open_because
# because_didn
# didn_think
# was_driving
# driving_it
# think_frightened
# you_when
# when_in
# last_place
# place_often
# often_would
# turn_around
# around_whilst
# whilst_cooking
# cooking_and
# and_chopping
# ingredients_and
# and_see
# still_open
# open_say
# say_that
# it_would
# been_about
# about_we
# we_didn
# have_one
# the_fridges
# fridges_with
# with_we
# re_privileged
# privileged_enough
# fridges_that
# play_little
# little_jingle
# jingle_to
# to_remind
# remind_us
# close_the
# door_but
# but_would
# say_on
# average_would
# would_to
# be_honest
# honest_on
# on_average
# it_got
# be_like
# like_five
# five_seconds
# seconds_because
# more_often
# often_than
# than_not
# getting_one
# thing_from
# from_the
# fridge_but
# if_making
# multiple_trips
# trips_yeah
# yeah_seconds
# seconds_josh
# josh_hey
# can_ask
# you_quick
# quick_question
# question_sorry
# just_to
# to_intervene
# intervene_um
# um_what
# what_was
# was_your
# walking_is
# is_focusing
# focusing_on
# on_fridges
# fridges_what
# your_fridge
# fridge_like
# like_do
# very_vivid
# memories_your
# your_memories
# memories_of
# fridge_as
# child_just
# just_have
# vivid_memories
# my_freezer
# freezer_that
# that_we
# to_defrost
# them_did
# guys_have
# defrost_how
# good_was
# was_defrosting
# defrosting_such
# good_fun
# fun_you
# get_all
# the_little
# little_great
# great_trays
# trays_let
# let_it
# drip_down
# down_and
# and_put
# put_pot
# pot_of
# of_boiling
# water_in
# there_yeah
# yeah_to
# to_speed
# speed_it
# up_yeah
# no_no
# no_but
# but_josh
# josh_hang
# on_hang
# on_you
# re_concerned
# concerned_about
# about_leaving
# open_and
# the_gases
# gases_are
# are_gonna
# gonna_have
# you_putting
# putting_boiling
# boiling_water
# fridge_oh
# oh_turn
# turn_it
# off_all
# all_frosted
# frosted_yeah
# it_gas
# gas_what
# what_gas
# gas_this
# this_gas
# gas_is
# why_you
# you_not
# not_men
# men_to
# transport_fridges
# fridges_and
# and_horizontally
# vertically_no
# no_you
# think_of
# the_freon
# re_thinking
# thinking_of
# of_freon
# factor_think
# think_with
# fridges_in
# our_our
# our_family
# family_fridge
# fridge_remember
# remember_having
# rubbish_seals
# seals_that
# that_strong
# childhood_yeah
# yeah_seals
# seals_replaced
# replaced_as
# and_people
# people_so
# so_reluctant
# reluctant_to
# it_why
# why_sir
# get_just
# just_get
# get_him
# him_done
# done_just
# them_done
# get_roof
# roof_seal
# seal_to
# it_they
# do_also
# also_the
# the_seals
# seals_is
# is_just
# just_roofs
# the_name
# name_it
# rude_the
# the_seal
# seal_isn
# isn_about
# about_the
# the_sealing
# the_character
# character_that
# singer_it
# it_comes
# comes_it
# does_your
# your_roof
# roof_tiling
# good_so
# previously_um
# um_we
# ve_we
# ve_sort
# of_looked
# looked_at
# at_how
# how_best
# best_to
# to_emulate
# emulate_certain
# sounds_with
# with_us
# us_from
# our_childhood
# through_pop
# pop_culture
# culture_the
# first_one
# one_we
# we_did
# we_tried
# tried_to
# to_recreate
# recreate_we
# we_sort
# of_tried
# most_realistic
# recreation_of
# of_tim
# tim_the
# the_toolman
# toolman_taylor
# home_improvement
# improvement_doing
# doing_his
# his_famous
# grunt_sound
# sound_and
# and_um
# um_ve
# ve_given
# given_we
# taking_little
# little_break
# break_from
# from_patchwork
# patchwork_we
# we_return
# return_to
# our_roots
# roots_we
# didn_actually
# actually_think
# think_about
# about_this
# this_before
# but_another
# guess_reference
# reference_another
# another_recreation
# recreation_um
# thank_god
# god_doing
# the_intro
# intro_for
# because_not
# not_going
# go_first
# it_ll
# be_an
# an_absolute
# absolute_car
# car_crash
# one_that
# re_doing
# is_from
# it_fran
# fran_fine
# fine_saying
# saying_oh
# oh_mr
# mr_sheffield
# all_get
# get_hot
# hot_shot
# shot_at
# at_saying
# sheffield_and
# the_key
# key_for
# for_copycat
# copycat_is
# realistic_recreation
# what_we
# re_after
# after_yeah
# right_um
# um_so
# so_who
# who_would
# would_like
# all_right
# right_josh
# got_first
# first_josh
# usually_you
# you_do
# do_kite
# kite_first
# first_up
# up_usually
# sitting_heavily
# heavily_fight
# fight_you
# waiting_for
# guys_who
# who_throws
# rubbish_yeah
# yeah_oh
# sheffield_think
# hung_on
# the_sheffield
# sheffield_yeah
# the_broto
# broto_on
# it_yeah
# yeah_don
# remember_friends
# friends_line
# line_having
# having_that
# that_good
# singing_boy
# boy_it
# was_christina
# christina_aguilera
# say_yeah
# yeah_impression
# impression_of
# an_impression
# impression_rd
# on_did
# go_next
# next_next
# next_ll
# ll_go
# bit_off
# off_mic
# mic_as
# that_josh
# did_and
# and_gonna
# gonna_close
# close_my
# my_eyes
# eyes_so
# so_can
# really_channel
# channel_her
# her_annoying
# annoying_voice
# voice_blah
# whether_we
# can_week
# week_we
# allow_aids
# aids_there
# there_no
# no_there
# no_aids
# aids_in
# just_your
# your_raw
# raw_voice
# voice_dion
# dion_shows
# shows_the
# of_conditions
# conditions_made
# made_mr
# not_bad
# bad_not
# bad_yeah
# was_very
# very_upper
# dad_christian
# at_very
# very_high
# high_you
# great_dynamics
# dynamics_then
# then_yeah
# yeah_any
# any_of
# of_us
# were_that
# honest_yeah
# yeah_josh
# started_well
# well_got
# got_the
# the_probably
# the_right
# right_notes
# notes_in
# there_but
# but_was
# was_way
# off_dion
# mean_you
# you_will
# will_probably
# probably_be
# the_closest
# oh_no
# no_too
# much_like
# like_caricature
# caricature_that
# didn_sound
# sound_like
# what_she
# she_sounded
# sounded_like
# if_we
# re_looking
# chat_it
# pretty_clear
# clear_that
# that_yes
# yes_as
# as_one
# although_daniel
# daniel_says
# says_that
# good_but
# yeah_christian
# you_seem
# seem_to
# the_front
# front_runner
# runner_someone
# someone_asks
# asks_whether
# can_hear
# hear_the
# the_original
# original_yeah
# yeah_think
# will_play
# play_the
# original_won
# won_be
# to_play
# play_it
# for_youtube
# live_but
# think_we
# it_right
# after_this
# now_josh
# josh_know
# know_you
# you_raised
# raised_this
# been_very
# very_reluctant
# to_tell
# story_that
# that_dion
# dion_has
# has_been
# been_dying
# dying_to
# to_hear
# this_podcast
# podcast_you
# it_has
# has_no
# no_legs
# ve_never
# never_heard
# heard_it
# but_desperate
# desperate_to
# hear_it
# of_how
# how_excited
# excited_dion
# dion_gets
# about_you
# you_telling
# telling_this
# this_particular
# particular_story
# it_entirely
# entirely_uninteresting
# uninteresting_it
# like_my
# my_favorite
# favorite_story
# haven_heard
# heard_in
# in_its
# its_entirety
# entirety_know
# there_not
# not_lot
# of_those
# categorization_of
# of_stories
# stories_but
# it_amazing
# amazing_anyway
# anyway_joshua
# joshua_thought
# tell_little
# of_story
# story_of
# childhood_so
# it_likely
# likely_to
# to_kick
# off_what
# was_and
# and_sorry
# sorry_this
# meant_it
# amazing_he
# he_unremarkable
# to_other
# other_people
# people_as
# as_find
# find_it
# unremarkable_as
# as_child
# child_we
# we_would
# would_go
# go_with
# my_grandparents
# grandparents_and
# would_drive
# drive_in
# the_combi
# combi_van
# van_and
# would_sit
# sit_at
# riversdale_station
# station_train
# train_station
# station_and
# watch_the
# the_trains
# trains_and
# and_that
# was_an
# afternoon_activity
# activity_would
# have_we
# have_packed
# packed_lunch
# lunch_in
# in_little
# little_plastic
# bag_backseat
# backseat_of
# the_cob
# cob_and
# it_had
# had_two
# railway_crossings
# crossings_for
# for_each
# each_side
# station_the
# the_traffic
# so_here
# the_ding
# ding_ding
# ding_going
# going_off
# off_and
# see_few
# few_trains
# trains_go
# go_past
# past_that
# great_afternoon
# afternoon_that
# so_funny
# funny_so
# so_to
# pet_to
# to_paint
# paint_picture
# picture_riversdale
# station_it
# it_sounds
# it_ours
# ours_out
# melbourne_it
# it_probably
# probably_eight
# minutes_from
# the_city
# city_yeah
# and_these
# normal_electric
# electric_trains
# trains_there
# interesting_about
# about_these
# these_trains
# trains_but
# love_the
# idea_love
# the_excitement
# that_surrounds
# surrounds_that
# that_day
# day_you
# know_getting
# lunch_together
# together_who
# who_you
# are_we
# we_gonna
# got_like
# your_impressions
# impressions_curious
# curious_as
# as_to
# whether_you
# guys_were
# oh_let
# let_go
# from_one
# one_till
# till_three
# three_so
# see_this
# line_that
# that_line
# line_and
# line_coming
# oh_that
# that_particularly
# particularly_busy
# busy_at
# this_time
# have_favourite
# favourite_trains
# trains_that
# were_watching
# watching_did
# actual_train
# train_don
# that_heavy
# heavy_into
# into_trains
# trains_don
# were_the
# the_kind
# of_kids
# kids_who
# who_had
# schedules_and
# and_were
# it_this
# one_and
# it_he
# um_don
# think_so
# we_just
# trains_going
# going_by
# by_as
# as_big
# big_as
# not_uncommon
# uncommon_for
# for_kids
# kids_like
# trucks_and
# big_train
# train_you
# know_big
# big_heavy
# heavy_things
# things_like
# like_um
# um_think
# train_going
# going_past
# past_it
# weren_like
# like_those
# those_kind
# of_obsessed
# obsessed_kids
# the_airport
# airport_and
# the_planes
# planes_because
# because_boeing
# and_no
# no_actually
# actually_that
# good_it
# point_because
# airport_usually
# usually_if
# can_half
# half_an
# an_hour
# hour_before
# before_ll
# ll_drive
# drive_down
# to_where
# the_where
# planes_fly
# over_just
# before_they
# they_hit
# hit_the
# the_runway
# runway_on
# time_because
# because_will
# will_like
# like_ll
# ll_do
# do_weeks
# won_take
# take_packed
# lunch_but
# but_ll
# did_but
# me_the
# connotation_of
# of_going
# some_pop
# train_just
# it_incredibly
# incredibly_funny
# but_christian
# christian_it
# of_sorry
# sorry_your
# issue_is
# is_with
# with_domestic
# domestic_metro
# metropolitan_train
# train_line
# line_very
# very_solid
# station_okay
# okay_yeah
# right_because
# because_when
# when_think
# it_when
# the_thai
# thai_market
# market_telmarine
# telmarine_airport
# go_just
# just_outside
# outside_if
# plane_that
# that_overhead
# overhead_then
# then_know
# domestic_plane
# plane_it
# like_like
# no_don
# don_really
# really_give
# give_shit
# shit_but
# an_international
# international_flight
# flight_if
# an_or
# something_will
# absolutely_lose
# lose_my
# my_shit
# shit_absolutely
# love_it
# have_qualification
# qualification_in
# is_airbus
# airbus_boeing
# sorry_but
# but_can
# can_can
# the_appeal
# appeal_of
# of_of
# of_watching
# and_watching
# watching_aeroplanes
# aeroplanes_because
# me_when
# when_watching
# watching_train
# train_go
# tend_to
# to_really
# really_lock
# lock_try
# to_lock
# lock_on
# face_that
# that_can
# see_going
# past_quite
# quickly_yeah
# of_unravels
# into_that
# that_people
# people_watching
# watching_like
# that_person
# person_going
# off_to
# do_where
# where_are
# they_going
# going_what
# what_stop
# stop_like
# it_quite
# quite_relaxing
# relaxing_and
# appeal_that
# that_way
# way_josh
# josh_it
# quite_it
# quite_interesting
# interesting_being
# being_on
# train_and
# and_having
# having_another
# another_train
# train_saddle
# saddle_up
# beside_you
# you_as
# well_and
# and_sort
# of_peeking
# in_instead
# instead_of
# going_know
# what_going
# on_or
# or_what
# going_on
# on_in
# this_opportunity
# opportunity_it
# opportunity_just
# to_look
# look_around
# around_and
# and_like
# at_some
# for_seconds
# seconds_and
# and_go
# go_yeah
# yeah_never
# gonna_see
# see_him
# him_again
# again_this
# this_has
# been_fun
# was_this
# this_great
# great_french
# french_performance
# was_on
# on_quite
# quite_while
# while_ago
# ago_and
# near_one
# the_pubs
# pubs_that
# that_runs
# runs_near
# richmond_station
# station_you
# could_sit
# sit_in
# pub_and
# and_watch
# and_what
# they_the
# the_artists
# artists_had
# had_particular
# particular_trains
# and_within
# within_each
# each_carriage
# carriage_of
# train_it
# was_different
# different_step
# step_of
# the_scene
# so_like
# the_carriage
# carriage_would
# past_and
# you_watch
# watch_it
# the_pub
# of_thing
# thing_play
# play_out
# out_over
# over_six
# carriages_it
# great_that
# pretty_cool
# that_pretty
# cool_but
# but_like
# this_the
# reason_why
# why_wanted
# wanted_josh
# the_reasons
# reasons_was
# it_made
# made_me
# me_reflect
# reflect_on
# on_weird
# weird_things
# things_that
# liked_did
# did_with
# my_folks
# folks_or
# or_did
# grandparents_you
# you_might
# might_remember
# remember_that
# that_um
# when_was
# was_younger
# younger_my
# parents_used
# take_us
# to_chinese
# chinese_restaurants
# restaurants_and
# and_when
# dad_used
# to_order
# order_soup
# he_used
# to_sir
# sir_asked
# asked_for
# for_nice
# nice_bucket
# to_him
# him_to
# to_cool
# cool_down
# down_soup
# soup_which
# is_what
# about_literally
# literally_one
# the_highlights
# highlights_of
# life_but
# but_the
# thing_was
# remembered_that
# that_when
# you_please
# please_do
# do_he
# he_coughing
# coughing_no
# can_because
# because_he
# he_might
# be_watching
# watching_so
# to_because
# because_about
# about_to
# bad_septum
# septum_as
# well_the
# that_remembered
# remembered_like
# embarrassing_things
# that_folks
# folks_did
# we_the
# the_start
# of_meal
# meal_chinese
# chinese_meal
# they_used
# put_down
# down_on
# the_table
# table_and
# and_in
# my_family
# family_when
# they_would
# would_arrive
# table_um
# um_that
# that_arrived
# arrived_sort
# after_we
# we_ordered
# ordered_sort
# the_food
# food_those
# the_main
# main_meals
# meals_and
# and_my
# dad_would
# would_ask
# to_take
# take_away
# away_the
# the_prawn
# prawn_crackers
# crackers_and
# bring_them
# them_back
# back_at
# the_meal
# cos_he
# he_didn
# us_watching
# this_or
# listening_to
# this_now
# now_they
# was_wrong
# that_but
# was_wondering
# have_any
# any_other
# other_stuff
# thing_could
# could_only
# only_come
# that_one
# one_prawn
# crackers_example
# example_of
# parents_being
# being_like
# like_but
# just_thinking
# thinking_my
# parents_are
# are_really
# really_wheat
# wheat_but
# but_do
# like_any
# any_examples
# examples_of
# of_things
# things_where
# your_parents
# are_like
# the_hell
# hell_are
# they_doing
# doing_what
# what_were
# were_they
# doing_back
# then_umm
# umm_don
# don_understand
# understand_why
# didn_let
# you_fill
# fill_up
# crackers_surely
# surely_that
# free_thing
# getting_if
# you_yell
# yell_up
# ll_eat
# eat_less
# less_food
# food_later
# later_yeah
# yeah_it
# idea_that
# that_wouldn
# wouldn_eat
# eat_the
# food_though
# though_think
# such_desperate
# desperate_fear
# fear_for
# for_parents
# they_ll
# ll_feel
# feel_that
# ll_fill
# up_early
# have_milky
# milky_way
# way_because
# it_won
# won_fill
# you_up
# up_like
# like_no
# no_do
# though_reckon
# reckon_reckon
# reckon_though
# though_when
# like_because
# dependents_think
# it_must
# must_be
# be_really
# interesting_having
# having_all
# all_your
# your_money
# money_spent
# by_someone
# someone_else
# else_every
# for_dinner
# dinner_you
# for_three
# people_and
# you_reckon
# reckon_ever
# ever_see
# nobody_back
# back_exactly
# exactly_you
# gonna_eat
# eat_this
# this_food
# food_ate
# ate_this
# this_fucking
# food_button
# button_take
# take_this
# fucking_prawn
# crackers_always
# always_think
# that_think
# just_the
# the_that
# that_and
# if_this
# food_left
# over_like
# what_food
# left_over
# parents_won
# be_what
# were_your
# parents_like
# like_in
# of_having
# having_food
# leftover_on
# the_plate
# plate_were
# they_being
# that_stuff
# stuff_without
# without_like
# just_whatever
# out_at
# whenever_got
# got_much
# much_but
# generally_it
# was_you
# you_finish
# finish_you
# always_strive
# strive_to
# to_finish
# finish_your
# your_meal
# was_always
# always_important
# important_everything
# that_which
# which_should
# be_finished
# finished_think
# the_goal
# goal_yeah
# likewise_think
# that_quite
# quite_common
# thing_for
# for_families
# families_right
# right_is
# whatever_on
# your_plate
# plate_gets
# gets_eaten
# stop_being
# being_fussy
# fussy_think
# think_for
# we_weren
# weren_allowed
# allowed_to
# be_fussy
# fussy_it
# case_of
# of_clean
# clean_your
# plate_up
# christian_did
# did_it
# with_tea
# ...
# christian_thinks
# thinks_the
# john_was
# was_fake
# yes_christian
# thinks_that
# that_wasn
# wasn_sorry
# dejan_thinks
# one_was
# was_real
# real_yes
# yes_that
# re_at
# at_yes
# yes_oh
# oh_great
# great_split
# split_you
# you_sorry
# dod_correct
# correct_the
# real_the
# one_about
# about_mr
# sun_that
# you_try
# to_bamboozle
# bamboozle_us
# us_with
# like_old
# old_timey
# timey_wording
# wording_like
# john_could
# could_come
# brother_jud
# jud_way
# way_oh
# oh_okay
# yeah_all
# okay_this
# is_called
# called_hickety
# hickety_pickety
# piketty_pickety
# pickety_my
# my_black
# black_hen
# hen_she
# she_lays
# eight_the
# the_gentlemen
# gentlemen_sometimes
# sometimes_nine
# sometimes_ten
# ten_hickety
# hen_okay
# okay_the
# second_is
# is_looking
# looking_for
# for_shoes
# can_find
# find_my
# my_shoes
# shoes_very
# very_loudly
# loudly_said
# shoes_they
# re_bright
# bright_and
# red_can
# use_my
# head_just
# just_found
# found_my
# were_under
# bed_the
# one_is
# fake_alright
# alright_here
# here_we
# we_go
# go_music
# music_plays
# plays_okay
# my_first
# the_missing
# missing_button
# button_by
# genevieve_betty
# betty_put
# on_her
# her_shoes
# shoes_and
# her_new
# new_pink
# pink_petticoat
# petticoat_alas
# alas_something
# was_amiss
# amiss_oh
# no_button
# button_is
# is_missing
# missing_from
# my_pink
# petticoat_then
# then_he
# he_searched
# searched_under
# the_sink
# sink_and
# and_even
# even_in
# shoes_but
# betty_couldn
# couldn_find
# find_her
# her_missing
# found_it
# it_her
# her_mother
# mother_said
# said_you
# you_dropped
# dropped_it
# my_sewing
# sewing_box
# box_little
# bit_he
# he_had
# forgotten_she
# she_had
# had_given
# given_it
# it_to
# to_her
# mother_stitched
# stitched_the
# on_betty
# betty_pink
# petticoat_and
# and_betty
# betty_was
# happy_again
# again_and
# then_second
# miss_polly
# polly_had
# had_dolly
# dolly_miss
# dolly_who
# who_was
# was_sick
# sick_sick
# sick_so
# so_she
# phoned_her
# her_doctor
# doctor_to
# be_quick
# quick_quick
# quick_the
# doctor_came
# came_out
# with_his
# his_bag
# and_hat
# hat_and
# and_knocked
# knocked_at
# door_with
# rat_tat
# tat_tat
# tat_he
# he_looked
# the_dolly
# dolly_and
# shook_his
# his_head
# head_and
# and_said
# said_miss
# polly_put
# her_straight
# to_bed
# he_wrote
# wrote_pad
# pad_for
# for_pill
# pill_pill
# pill_of
# being_the
# the_bat
# bat_ll
# be_back
# morning_with
# my_bill
# bill_bill
# american_doctors
# doctors_yeah
# yeah_uh
# uh_cushion
# considering_dealin
# dealin_obviously
# obviously_doesn
# what_would
# have_nursery
# nursery_right
# gonna_go
# was_written
# by_you
# you_joe
# joe_pretty
# pretty_certain
# certain_ve
# that_definitely
# definitely_real
# how_is
# you_found
# found_the
# oh_mine
# mine_doesn
# doesn_need
# rhyme_don
# know_just
# just_was
# was_felt
# previously_they
# ve_come
# come_so
# so_so
# easily_to
# to_me
# me_could
# say_when
# started_writing
# writing_one
# one_before
# before_this
# first_these
# first_two
# two_lines
# lines_and
# then_abandoned
# abandoned_it
# is_this
# is_meant
# the_nursery
# nursery_rhyme
# was_gonna
# gonna_write
# write_farmer
# farmer_joe
# joe_was
# an_early
# riser_his
# his_medication
# medication_was
# was_made
# made_by
# by_pfizer
# god_what
# what_bumper
# bumper_bumper
# bumper_show
# show_um
# last_thing
# about_oh
# god_this
# this_been
# going_for
# four_hours
# hours_and
# that_uh
# uh_what
# gonna_play
# play_um
# your_favorite
# favorite_and
# not_gonna
# gonna_sing
# sing_favorite
# tell_me
# me_what
# favorite_but
# gonna_ask
# guys_really
# really_what
# favorite_floor
# floor_weight
# weight_loss
# loss_law
# law_yeah
# could_still
# still_have
# have_dual
# dual_meaning
# though_maybe
# maybe_start
# start_talking
# about_and
# listeners_will
# will_sort
# of_gather
# gather_an
# understanding_of
# of_what
# what_floor
# floor_actually
# mean_um
# my_do
# want_me
# me_to
# kick_this
# off_day
# day_on
# on_yeah
# yeah_sure
# sure_so
# my_top
# top_my
# favorite_type
# type_of
# of_flooring
# flooring_now
# now_know
# took_it
# it_took
# took_molt
# molt_like
# like_multiple
# approach_to
# like_how
# how_wanted
# to_grade
# the_type
# flooring_and
# and_judged
# judged_the
# flooring_on
# on_on
# on_aesthetics
# aesthetics_on
# sensation_and
# that_both
# touch_that
# that_smell
# smell_that
# taste_and
# then_also
# the_maintenance
# maintenance_of
# that_floor
# floor_so
# the_flooring
# flooring_that
# that_ve
# picked_is
# is_freshly
# freshly_cut
# cut_grass
# strange_freshly
# grass_is
# flooring_because
# not_only
# only_does
# does_it
# it_have
# most_operative
# operative_thing
# sensation_we
# all_are
# are_very
# very_familiar
# familiar_with
# the_smell
# smell_of
# of_freshly
# we_know
# the_feel
# feel_underfoot
# underfoot_of
# grass_but
# also_but
# the_color
# the_spectacle
# spectacle_the
# the_vibrant
# vibrant_green
# green_in
# pantone_named
# named_this
# this_green
# green_the
# color_of
# the_year
# year_can
# can_just
# say_christian
# christian_if
# were_having
# having_go
# go_at
# at_me
# me_before
# before_about
# about_what
# nursery_that
# rhyme_is
# what_about
# about_haven
# got_you
# you_for
# not_knowing
# knowing_what
# floor_is
# sorry_dionne
# dionne_define
# define_floor
# floor_to
# me_interior
# marvel_stadium
# stadium_where
# where_weather
# weather_is
# the_roof
# roof_there
# there_cushion
# cushion_of
# that_actually
# actually_shot
# shot_from
# the_mcg
# mcg_you
# change_the
# the_camera
# camera_angle
# angle_little
# you_actually
# actually_see
# see_what
# what_playing
# live_on
# screen_yes
# yes_so
# favorite_is
# grass_when
# you_spill
# something_on
# on_freshly
# good_experience
# experience_building
# building_something
# fresh_you
# go_across
# across_you
# don_worry
# josh_and
# it_cut
# it_looks
# looks_its
# its_best
# best_and
# can_always
# return_it
# that_state
# state_just
# just_by
# by_cutting
# again_it
# like_getting
# getting_haircut
# for_grass
# grass_what
# about_when
# it_dries
# get_bit
# of_dead
# dead_patch
# what_happens
# happens_then
# re_fixing
# that_with
# with_fresh
# fresh_with
# with_freshly
# good_irrigation
# irrigation_josh
# josh_okay
# okay_do
# they_cut
# cut_freshly
# grass_they
# they_ask
# the_grass
# grass_if
# if_they
# they_want
# want_any
# any_product
# product_in
# in_it
# know_don
# get_how
# do_they
# they_get
# that_weed
# weed_crosshatch
# crosshatch_on
# on_that
# that_on
# football_fields
# fields_made
# made_another
# another_podcast
# can_we
# can_keep
# keep_on
# on_doing
# science_stuff
# stuff_it
# doesn_work
# work_nice
# deal_what
# favorite_flooring
# look_my
# flooring_didn
# to_think
# long_at
# at_all
# flooring_is
# is_when
# go_into
# into_an
# an_old
# old_house
# say_you
# re_renting
# renting_the
# house_or
# just_bought
# bought_the
# pull_up
# the_carpet
# carpet_and
# hardwood_timber
# timber_floors
# floors_yeah
# yeah_there
# nothing_better
# better_as
# as_it
# stunning_just
# just_don
# clip_it
# put_product
# so_good
# good_josh
# all_heard
# heard_you
# you_say
# say_then
# was_no
# like_cold
# cold_hardwood
# hardwood_floor
# floor_it
# it_cold
# it_my
# my_babri
# babri_fight
# fight_during
# of_cold
# hardwood_floors
# floors_is
# freezing_in
# in_wintertime
# wintertime_so
# so_loud
# loud_it
# echoing_around
# around_the
# house_like
# like_solid
# timber_it
# so_beautiful
# beautiful_it
# the_beauty
# beauty_of
# just_displaces
# displaces_like
# difficult_it
# to_whether
# whether_it
# difficult_to
# clean_or
# or_whether
# whether_there
# know_little
# little_tax
# tax_that
# that_result
# result_in
# in_you
# take_getting
# getting_toes
# toes_taken
# taken_off
# off_your
# your_feet
# it_absolutely
# stunning_and
# go_we
# see_resounding
# resounding_in
# floor_wins
# wins_didn
# didn_win
# win_the
# young_duke
# duke_at
# at_for
# for_wins
# wins_so
# really_honed
# honed_in
# the_aesthetics
# aesthetics_of
# it_seriously
# seriously_it
# it_christian
# christian_what
# think_like
# one_with
# know_with
# you_day
# on_all
# way_hardwood
# floor_if
# have_read
# read_the
# the_brief
# brief_of
# this_segment
# wrong_then
# then_would
# have_picked
# picked_very
# light_hardwood
# floor_the
# the_it
# of_aesthetics
# aesthetics_would
# would_mean
# mean_it
# comparable_with
# with_concrete
# concrete_slab
# slab_for
# me_big
# bit_hardwood
# floor_just
# just_that
# the_sound
# of_tiptoeing
# tiptoeing_on
# on_hardwood
# floor_reminds
# of_christmas
# christmas_this
# for_the
# smell_the
# cut_card
# card_would
# would_for
# for_ever
# be_more
# more_anticipation
# anticipation_for
# for_josh
# josh_response
# aren_you
# just_interested
# interested_because
# obviously_not
# not_hardwood
# floor_or
# or_grass
# just_only
# only_just
# just_hanging
# hanging_off
# off_but
# has_to
# say_josh
# josh_when
# when_your
# honest_josh
# anywhere_near
# near_carpet
# carpet_am
# am_going
# to_tear
# you_to
# to_pieces
# ve_gone
# gone_for
# for_what
# what_could
# could_see
# great_all
# all_rounder
# rounder_going
# for_linoleum
# floor_your
# your_grandparents
# grandparents_place
# place_before
# before_you
# to_watch
# trains_ll
# what_love
# love_about
# it_easy
# easy_to
# your_spill
# spill_cyst
# cyst_back
# ball_on
# floor_get
# up_mop
# mop_it
# easy_you
# can_mop
# mop_that
# floor_easily
# easily_it
# very_clean
# clean_do
# how_good
# good_hardwood
# is_you
# spill_spagbol
# spagbol_looks
# looks_better
# yeah_give
# give_him
# him_chance
# chance_so
# ll_click
# re_on
# on_par
# par_for
# for_cleaning
# cleaning_mate
# perfectly_ll
# you_that
# that_for
# hub_your
# your_grass
# is_grasses
# grasses_in
# thing_like
# it_little
# soft_it
# got_bit
# of_sponge
# sponge_to
# to_it
# you_tiptoeing
# tiptoeing_through
# through_that
# for_christmas
# doesn_it
# it_feel
# feel_great
# not_freezing
# cold_in
# in_winter
# winter_when
# you_come
# come_through
# there_on
# on_cold
# cold_winter
# winter_morning
# morning_it
# not_icy
# icy_cold
# cold_on
# your_toes
# toes_and
# getting_frostbite
# frostbite_because
# what_happen
# happen_what
# happens_when
# it_bubbles
# not_bubbly
# bubbly_ve
# never_had
# bubbling_winos
# winos_bubbling
# bubbling_is
# not_the
# problem_josh
# josh_what
# the_look
# look_of
# looks_shocking
# shocking_you
# different_kinds
# kinds_of
# of_designs
# designs_and
# quite_found
# quite_eco
# eco_it
# made_of
# of_natural
# natural_things
# things_not
# like_things
# things_argument
# argument_that
# that_last
# last_fell
# fell_down
# to_buy
# buy_bamboo
# bamboo_underwear
# underwear_and
# all_great
# great_bamboo
# bamboo_grows
# grows_like
# grass_oh
# it_costs
# costs_an
# an_incredible
# of_energy
# energy_goes
# manufacturing_bamboo
# bamboo_thanks
# thanks_bamboo
# ve_turned
# turned_something
# something_into
# into_something
# so_damn
# damn_good
# it_such
# re_like
# like_grass
# grass_and
# doesn_necessarily
# necessarily_work
# work_but
# josh_get
# get_that
# that_clay
# clay_easy
# clean_like
# to_more
# more_likely
# likely_that
# that_sauce
# sauce_it
# bit_pad
# pad_it
# good_acoustics
# acoustics_in
# it_grater
# grater_it
# it_might
# might_not
# not_be
# most_aesthetically
# aesthetically_you
# have_that
# the_high
# high_price
# price_tag
# tag_of
# polished_wood
# wood_floors
# floors_or
# or_your
# your_polish
# concrete_or
# your_interior
# interior_grass
# it_takes
# takes_lot
# of_boxes
# boxes_for
# me_and
# and_for
# me_that
# what_laura
# laura_is
# floor_on
# that_note
# note_was
# actually_gonna
# go_was
# had_any
# any_second
# second_or
# or_third
# third_places
# probably_just
# just_had
# different_variants
# variants_of
# of_grass
# to_we
# break_for
# for_about
# about_five
# five_minutes
# minutes_now
# now_and
# your_opportunity
# opportunity_you
# you_and
# it_your
# opportunity_to
# write_down
# down_your
# your_really
# really_goods
# goods_and
# get_chance
# chance_to
# on_air
# air_now
# now_also
# also_also
# haven_yet
# yet_mentioned
# mentioned_why
# re_here
# should_know
# know_by
# by_now
# and_make
# mention_it
# chat_for
# might_just
# just_be
# be_in
# the_running
# running_you
# re_talking
# ll_see
# you_in
# in_few
# few_minutes
# really_you
# what_really
# really_go
# go_up
# the_bump
# bump_bump
# bump_really
# good_youtube
# live_and
# getting_those
# those_really
# good_zine
# zine_we
# we_do
# live_hearing
# hearing_you
# re_really
# good_and
# week_you
# what_linda
# linda_dolan
# dolan_thinks
# thinks_is
# good_when
# re_controlling
# controlling_the
# orcs_cord
# cord_and
# you_notice
# notice_someone
# someone_shazam
# song_that
# you_chose
# chose_and
# patrick_negus
# negus_thinks
# is_really
# getting_you
# have_new
# new_message
# message_in
# mygov_inbox
# inbox_message
# message_and
# it_turns
# turns_out
# be_something
# something_benign
# benign_and
# caitlyn_bolo
# bolo_groom
# groom_thinks
# you_forgot
# forgot_you
# put_your
# your_washing
# washing_on
# maybe_your
# your_flatmates
# flatmates_had
# had_put
# dryer_for
# you_yes
# yes_thank
# much_for
# to_welcome
# welcome_to
# to_patch
# patch_work
# work_for
# another_week
# we_flagged
# flagged_at
# show_that
# of_sort
# from_patrick
# while_josh
# josh_maybe
# maybe_ll
# ll_throw
# over_to
# to_sort
# of_explain
# explain_why
# ve_taken
# taken_this
# this_course
# course_of
# of_action
# action_yeah
# re_taking
# break_it
# just_as
# as_sure
# sure_lot
# experiencing_here
# in_australia
# australia_cove
# cove_it
# been_pretty
# pretty_tough
# tough_for
# for_lot
# of_people
# know_me
# me_personally
# personally_ve
# ve_struggled
# struggled_bit
# with_it
# these_guys
# been_really
# supportive_and
# and_helping
# helping_me
# me_through
# really_difficult
# difficult_but
# are_struggling
# struggling_make
# sure_you
# you_reach
# reach_out
# your_friends
# friends_and
# can_help
# help_you
# break_just
# of_get
# get_hold
# and_everything
# everything_again
# really_love
# and_really
# really_producing
# producing_this
# stuff_to
# guys_so
# re_hoping
# hoping_to
# it_as
# as_soon
# soon_as
# as_we
# can_yeah
# be_communicating
# communicating_with
# with_patrons
# during_the
# the_week
# week_as
# what_will
# will_do
# guys_yeah
# really_appreciate
# appreciate_everyone
# everyone_support
# support_and
# everyone_coming
# coming_along
# along_to
# lives_it
# it_been
# been_massive
# massive_help
# help_but
# we_hope
# hope_everyone
# everyone_out
# was_sort
# to_not
# not_talk
# about_sort
# happening_in
# world_too
# much_to
# everyone_little
# of_distraction
# it_gets
# gets_the
# the_distraction
# distraction_for
# ourselves_as
# everything_that
# happening_but
# hopefully_everything
# everything_will
# will_settle
# settle_down
# really_soon
# soon_but
# yeah_bear
# bear_with
# while_we
# go_on
# on_break
# break_but
# of_course
# course_on
# on_social
# social_media
# media_you
# can_hit
# hit_us
# up_whenever
# whenever_you
# you_we
# instagram_facebook
# facebook_and
# and_twitter
# twitter_and
# will_always
# always_be
# christian_is
# is_there
# there_anything
# else_you
# to_add
# add_at
# all_putting
# putting_on
# well_mean
# just_great
# great_to
# both_with
# with_me
# me_really
# really_guess
# final_thing
# add_for
# this_episode
# episode_before
# we_throw
# throw_to
# patches_you
# know_of
# course_someone
# someone_needs
# to_win
# prize_mean
# who_it
# it_could
# be_but
# seems_though
# everyone_is
# is_here
# here_because
# the_buzz
# buzz_of
# prize_yes
# yes_buzz
# buzz_don
# prize_was
# was_christian
# christian_got
# got_on
# on_our
# instagram_and
# listening_this
# this_podcaster
# podcaster_you
# not_on
# our_instagram
# instagram_account
# account_don
# don_post
# post_funny
# shit_josh
# josh_doesn
# doesn_post
# post_anything
# christian_posts
# posts_the
# the_funniest
# funniest_stuff
# stuff_on
# instagram_so
# so_please
# please_search
# search_welcome
# patchwork_but
# christian_cannot
# mind_if
# if_award
# award_our
# our_the
# prize_to
# to_someone
# someone_christian
# christian_even
# though_joy
# joy_is
# big_price
# price_goes
# goes_up
# until_about
# about_four
# four_minutes
# minutes_ago
# there_wasn
# wasn_big
# prize_but
# but_now
# now_there
# is_huge
# huge_okay
# the_huge
# huge_prize
# gonna_give
# give_it
# someone_who
# who_showed
# showed_up
# chat_and
# can_all
# all_piss
# off_after
# after_ve
# ve_an
# an_answer
# answer_because
# because_know
# only_reason
# ve_stuck
# around_for
# this_long
# long_but
# but_gonna
# to_hannah
# hannah_douglas
# douglas_because
# because_she
# she_wrote
# um_you
# even_know
# prize_is
# you_win
# win_it
# it_anyway
# so_congratulations
# douglas_get
# get_us
# us_up
# on_instagram
# instagram_or
# facebook_or
# or_twitter
# gonna_send
# out_welcome
# to_patchwork
# patchwork_mug
# mug_that
# been_bloody
# bloody_wanting
# wanting_for
# long_ever
# ever_near
# near_but
# out_wine
# wine_hannah
# hannah_so
# so_he
# he_still
# still_around
# yeah_hit
# you_big
# prize_think
# had_in
# mind_wasn
# wasn_christian
# christian_don
# just_quickly
# quickly_as
# well_some
# some_game
# game_boys
# boys_news
# doing_big
# big_special
# special_live
# for_vcr
# vcr_fest
# fest_it
# it_digital
# digital_festivals
# run_by
# by_melbourne
# melbourne_fringe
# fringe_coming
# coming_up
# up_at
# of_august
# august_we
# on_august
# august_nd
# nd_so
# stream_for
# for_that
# and_also
# also_we
# doing_our
# our_out
# out_fortnightly
# streams_as
# well_ve
# just_head
# head_to
# boys_comedy
# comedy_look
# youtube_and
# it_lot
# of_fun
# fun_fun
# variety_show
# show_christians
# popped_in
# in_couple
# of_times
# times_it
# nice_but
# yeah_make
# you_tune
# tune_into
# well_alright
# alright_as
# do_every
# every_week
# we_saw
# saw_new
# new_patch
# patch_into
# into_our
# our_quilt
# quilt_of
# what_patch
# patch_did
# you_saw
# saw_in
# in_this
# my_patch
# patch_this
# week_is
# at_your
# your_local
# local_airport
# airport_watching
# planes_coming
# coming_to
# to_land
# land_on
# the_new
# hardwood_runway
# runway_christian
# say_this
# week_thank
# you_josh
# josh_this
# week_sewed
# sewed_into
# into_my
# patch_our
# our_favorite
# little_host
# host_who
# was_embarrassed
# embarrassed_the
# they_gave
# gave_him
# him_little
# little_roast
# roast_for
# forgetting_to
# make_his
# his_segment
# segment_ryan
# dion_what
# you_sew
# sew_into
# into_your
# your_patch
# week_my
# christian_on
# his_hands
# hands_and
# and_knees
# knees_ripping
# the_line
# line_oh
# josh_laid
# laid_in
# in_his
# house_in
# in_favor
# favor_of
# old_ray
# ray_films
# films_thank
# for_listening
# to_velvet
# velvet_the
# patchwork_for
# for_another
# back_very
# very_soon
# get_on
# our_social
# media_we
# ll_let
# know_but
# but_in
# the_meantime
# meantime_ve
# dealing_josh
# been_christian

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def make_quadgrams(texts):
    return [quadgram_mod[trigram_mod[doc]] for doc in texts]

# %%
len(stop_words)
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# not used
data_words_trigrams = make_trigrams(data_words_nostops)

# %%
type(data)
len(data)
type(df)
len(df)
len(data_words)
len(data_words_nostops)
# Out:
# 1586

# %%
#nlp = en_core_web_sm.load()
nlp = spacy.load("en_core_web_sm")

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %%
bah = spacy.explain('eating')

# %%
type(data_words_bigrams)
# Out:
# list

# %%
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'PROPN']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

def lemmatisation(texts):
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc])
    return texts_out
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data_lemmatized = lemmatization(data_words_bigrams)
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data_lemmatised = lemmatisation(data_words_bigrams)
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#line_nbr = 18

for line_nbr in range(700,720):
    print("['"+df.loc[line_nbr].values[0]+"']")
    print(data_words[line_nbr])
    print(data_words_nostops[line_nbr])
    print(data_words_bigrams[line_nbr])
    print(data_lemmatised[line_nbr])
    print(data_lemmatized[line_nbr])
    print('\n')
# Out:
# ['firm line on this without having the the']
# ['firm', 'line', 'on', 'this', 'without', 'having', 'the', 'the']
# ['firm', 'line', 'without']
# ['firm', 'line', 'without']
# ['firm', 'line', 'without']
# ['firm', 'line']
#
#
# ['concern of being worried about every']
# ['concern', 'of', 'being', 'worried', 'about', 'every']
# ['concern', 'worried', 'every']
# ['concern', 'worried', 'every']
# ['concern', 'worry', 'every']
# ['concern', 'worry']
#
#
# ['other part in your life that you're not']
# ['other', 'part', 'in', 'your', 'life', 'that', 'you', 're', 'not']
# ['part', 'life']
# ['part', 'life']
# ['part', 'life']
# ['part', 'life']
#
#
# ['conserving energy yeah']
# ['conserving', 'energy', 'yeah']
# ['conserving', 'energy', 'yeah']
# ['conserving', 'energy', 'yeah']
# ['conserve', 'energy', 'yeah']
# ['conserve', 'energy']
#
#
# ['it's a good point but I think you're']
# ['it', 'good', 'point', 'but', 'think', 'you', 're']
# ['good', 'point', 'think']
# ['good', 'point', 'think']
# ['good', 'point', 'think']
# ['good', 'point', 'think']
#
#
# ['probably better to just take what you']
# ['probably', 'better', 'to', 'just', 'take', 'what', 'you']
# ['probably', 'better', 'take']
# ['probably', 'better', 'take']
# ['probably', 'well', 'take']
# ['take']
#
#
# ['can get right so if that's if that's the']
# ['can', 'get', 'right', 'so', 'if', 'that', 'if', 'that', 'the']
# ['get', 'right']
# ['get', 'right']
# ['get', 'right']
# ['right']
#
#
# ['little thing that I want to do to put my']
# ['little', 'thing', 'that', 'want', 'to', 'do', 'to', 'put', 'my']
# ['little', 'thing', 'want', 'put']
# ['little', 'thing', 'want', 'put']
# ['little', 'thing', 'want', 'put']
# ['little', 'thing', 'want', 'put']
#
#
# ['my green step on the globe']
# ['my', 'green', 'step', 'on', 'the', 'globe']
# ['green', 'step', 'globe']
# ['green', 'step', 'globe']
# ['green', 'step', 'globe']
# ['green', 'step', 'globe']
#
#
# ['[Laughter]']
# ['laughter']
# ['laughter']
# ['laughter']
# ['laughter']
# ['laughter']
#
#
# ['do you know what I did recently though I']
# ['do', 'you', 'know', 'what', 'did', 'recently', 'though']
# ['know', 'recently', 'though']
# ['know', 'recently', 'though']
# ['know', 'recently', 'though']
# ['know']
#
#
# ['decided for no reason every time I've']
# ['decided', 'for', 'no', 'reason', 'every', 'time', 've']
# ['decided', 'reason', 'every', 'time']
# ['decided', 'reason', 'every', 'time']
# ['decide', 'reason', 'every', 'time']
# ['decide', 'reason', 'time']
#
#
# ['always bought like if it's black point']
# ['always', 'bought', 'like', 'if', 'it', 'black', 'point']
# ['always', 'bought', 'like', 'black', 'point']
# ['always', 'bought', 'like', 'black', 'point']
# ['always', 'buy', 'like', 'black', 'point']
# ['buy', 'black', 'point']
#
#
# ['of my life I've always had a shit fridge']
# ['of', 'my', 'life', 've', 'always', 'had', 'shit', 'fridge']
# ['life', 'always', 'shit', 'fridge']
# ['life', 'always', 'shit', 'fridge']
# ['life', 'always', 'shit', 'fridge']
# ['life', 'shit', 'fridge']
#
#
# ['and I was like you know what I'm gonna']
# ['and', 'was', 'like', 'you', 'know', 'what', 'gonna']
# ['like', 'know', 'gonna']
# ['like', 'know', 'gonna']
# ['like', 'know', 'go', 'to']
# ['know', 'go']
#
#
# ['buy a new one because you're a nut job']
# ['buy', 'new', 'one', 'because', 'you', 're', 'nut', 'job']
# ['buy', 'new', 'one', 'nut', 'job']
# ['buy', 'new', 'one', 'nut', 'job']
# ['buy', 'new', 'one', 'nut', 'job']
# ['buy', 'new', 'nut', 'job']
#
#
# ['if you buy a new fridge or you cut over']
# ['if', 'you', 'buy', 'new', 'fridge', 'or', 'you', 'cut', 'over']
# ['buy', 'new', 'fridge', 'cut']
# ['buy', 'new', 'fridge', 'cut']
# ['buy', 'new', 'fridge', 'cut']
# ['buy', 'new', 'fridge', 'cut']
#
#
# ['a new car but I said look I'm gonna buy']
# ['new', 'car', 'but', 'said', 'look', 'gonna', 'buy']
# ['new', 'car', 'said', 'look', 'gonna', 'buy']
# ['new', 'car', 'said', 'look', 'gonna', 'buy']
# ['new', 'car', 'say', 'look', 'go', 'to', 'buy']
# ['new', 'car', 'say', 'look', 'go', 'buy']
#
#
# ['one for for 450 bucks or something and I']
# ['one', 'for', 'for', 'bucks', 'or', 'something', 'and']
# ['one', 'bucks', 'something']
# ['one', 'bucks', 'something']
# ['one', 'buck', 'something']
# ['buck']
#
#
# ['bought it and I upsized and now I have']
# ['bought', 'it', 'and', 'upsized', 'and', 'now', 'have']
# ['bought', 'upsized']
# ['bought', 'upsized']
# ['buy', 'upsized']
# ['buy', 'upsized']
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Dictionary

# %%
id2word = corpora.Dictionary(data_lemmatized)

id2word_2 = corpora.Dictionary(data_lemmatised)
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# term frequency
id2word.save_as_text('dictionary_patch69.txt')
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
id2word_filtered
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
patch_dict = pd.read_csv('C:\\Users\\Sally\\WTP\\dictionary_patch69.csv',names=['id','word','freq'],sep='\s+')
#patch_dict = pd.read_csv('dictionary_patch69.txt',names=['id','word','freq'],sep='\s+')
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <>:1: DeprecationWarning: invalid escape sequence \s
# <>:1: DeprecationWarning: invalid escape sequence \s
# <>:1: DeprecationWarning: invalid escape sequence \s
# <ipython-input-155-b0b4a02e9931>:1: DeprecationWarning: invalid escape sequence \s
#   patch_dict = pd.read_csv('C:\\Users\\Sally\\WTP\\dictionary_patch69.csv',names=['id','word','freq'],sep='\s+')

# %%
patch_dict.sort_values(by='freq',ascending=False).head(10)
# Out:
#        id    word   freq
# 422    77      go  113.0
# 983   190   think   79.0
# 530    80    know   74.0
# 414    53     get   69.0
# 982    66   thing   52.0
# 424     1    good   51.0
# 782    12  really   49.0
# 1093   28   would   34.0
# 835   136     say   32.0
# 387   571  fridge   27.0

# %%
id2word_filtered = id2word.filter_extremes(no_below=5, no_above=0.5, keep_n=1)
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[195])

# %%
dc = patch_dict.dropna()

# %%
dc
# Out:
#         id        word  freq
# 1      934     abandon   1.0
# 2      334        able   4.0
# 3      155    absolute   3.0
# 4      163  absolutely   8.0
# 5      508  accumulate   2.0
# ...    ...         ...   ...
# 1099    73   yesterday   1.0
# 1100  1037         yet   1.0
# 1101    21       young   4.0
# 1102   708     youtube   3.0
# 1103  1038        zine   1.0
#
# [1103 rows x 3 columns]

# %%
dc['len'] = dc['word'].str.len()
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dc.head()
# Out:
#     id        word  freq  len
# 1  934     abandon   1.0    7
# 2  334        able   4.0    4
# 3  155    absolute   3.0    8
# 4  163  absolutely   8.0   10
# 5  508  accumulate   2.0   10

# %%
dc.sort_values(by='len',ascending=False)
# Out:
#         id            word   freq  len
# 180   1075  congratulation    1.0   14
# 138    718  categorization    1.0   14
# 1031   716   uninteresting    1.0   13
# 510    764   international    1.0   13
# 764    765   qualification    1.0   13
# ...    ...             ...    ...  ...
# 546    261             leg    4.0    3
# 422     77              go  113.0    2
# 253    392              do    5.0    2
# 519     23              jp    1.0    2
# 316   1082               f    1.0    1
#
# [1103 rows x 4 columns]

# %%
popular_words = patch_dict[patch_dict.freq > 20]

# %%
popular_words
# Out:
#        id    word   freq
# 63     29    back   22.0
# 73    225     bed   21.0
# 81    123     big   26.0
# 82    198     bit   25.0
# 361   464   floor   26.0
# 387   571  fridge   27.0
# 414    53     get   69.0
# 422    77      go  113.0
# 424     1    good   51.0
# 432    17   great   21.0
# 530    80    know   74.0
# 569   199  little   26.0
# 574   154    look   22.0
# 589   232    make   24.0
# 763   221     put   26.0
# 782    12  really   49.0
# 835   136     say   32.0
# 949   181   stuff   22.0
# 967    41    take   26.0
# 973   247     tea   22.0
# 982    66   thing   52.0
# 983   190   think   79.0
# 1007  249   towel   21.0
# 1037   24     use   27.0
# 1058   70    want   26.0
# 1093   28   would   34.0

# %%
type(id2word) #gensim.corpora.dictionary.Dictionary
type(texts) #list
type(corpus) #list
# Out:
# list

# %%
chosen_num = 1000
print(data[chosen_num])
print(data_words_nostops[chosen_num])
print(corpus[chosen_num])
print(texts[chosen_num])
# Out:
# bring them back at the end of the meal
# ['bring', 'back', 'end', 'meal']
# [(17, 1), (79, 1), (862, 1)]
# ['bring', 'end', 'meal']

# %% [markdown]
# ## Topic Modelling

# %%
n = 5
w = 8
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                            id2word=id2word,
                                            num_topics=n,
                                            #random_state=100,
                                            #update_every=1,
                                            #chunksize=10,
                                            #passes=20,
                                            #alpha='symmetric',                                            
                                            #alpha=50,
                                            iterations=30,
                                            per_word_topics=True
                                           )

pprint(lda_model.show_topics(n,w,formatted=False))
# Out:
# [(0,
#   [('fridge', 0.016340876),
#    ('would', 0.010679233),
#    ('tea', 0.010644891),
#    ('make', 0.010639361),
#    ('great', 0.010585879),
#    ('little', 0.009491986),
#    ('towel', 0.0083274),
#    ('keep', 0.008313022)]),
#  (1,
#   [('think', 0.032570638),
#    ('christian', 0.022744492),
#    ('big', 0.02045558),
#    ('know', 0.01911858),
#    ('good', 0.014624247),
#    ('put', 0.014141887),
#    ('thing', 0.012502731),
#    ('use', 0.011575513)]),
#  (2,
#   [('go', 0.069128506),
#    ('know', 0.0350399),
#    ('say', 0.014917261),
#    ('towel', 0.014675139),
#    ('fridge', 0.01401661),
#    ('take', 0.01129133),
#    ('tea', 0.011243121),
#    ('think', 0.010232596)]),
#  (3,
#   [('thing', 0.024970245),
#    ('get', 0.021506311),
#    ('think', 0.021385001),
#    ('go', 0.018201636),
#    ('second', 0.0121181505),
#    ('bed', 0.012071413),
#    ('make', 0.011899298),
#    ('know', 0.010427163)]),
#  (4,
#   [('good', 0.030638073),
#    ('get', 0.028236795),
#    ('josh', 0.024530381),
#    ('go', 0.022316998),
#    ('music', 0.012314508),
#    ('guy', 0.011685273),
#    ('live', 0.009067992),
#    ('think', 0.008948751)])]

# %% [markdown]
# ## Topic Model using Mallet wrapper

# %%
import os
mallet_path = "C:/Users/Sally/WTP/mallet-2.0.8/bin/mallet"
os.environ['MALLET_HOME'] = 'C:/Users/Sally/WTP/mallet-2.0.8'

# %%
num_topics = 8
num_words = 10

ldamallet = gensim.models.wrappers.LdaMallet(mallet_path
                                            ,corpus=corpus
                                            ,num_topics=num_topics
                                            ,id2word=id2word
                                            #,iterations=10
                                             )
pprint(ldamallet.show_topics(num_topics,num_words,formatted=False))
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [(0,
#   [('fridge', 0.10101010101010101),
#    ('floor', 0.06565656565656566),
#    ('time', 0.05555555555555555),
#    ('give', 0.050505050505050504),
#    ('ray', 0.04040404040404041),
#    ('buy', 0.027777777777777776),
#    ('feel', 0.025252525252525252),
#    ('show', 0.022727272727272728),
#    ('post', 0.020202020202020204),
#    ('line', 0.020202020202020204)]),
#  (1,
#   [('good', 0.12385321100917432),
#    ('make', 0.05504587155963303),
#    ('train', 0.03669724770642202),
#    ('watch', 0.034403669724770644),
#    ('storage', 0.02522935779816514),
#    ('hardwood', 0.02522935779816514),
#    ('people', 0.022935779816513763),
#    ('point', 0.022935779816513763),
#    ('wool', 0.016055045871559634),
#    ('ding', 0.016055045871559634)]),
#  (2,
#   [('christian', 0.10666666666666667),
#    ('favorite', 0.042666666666666665),
#    ('parent', 0.02666666666666667),
#    ('box', 0.024),
#    ('cold', 0.021333333333333333),
#    ('day', 0.021333333333333333),
#    ('door', 0.021333333333333333),
#    ('plastic', 0.018666666666666668),
#    ('talk', 0.018666666666666668),
#    ('sort', 0.018666666666666668)]),
#  (3,
#   [('put', 0.06521739130434782),
#    ('grass', 0.043478260869565216),
#    ('week', 0.043478260869565216),
#    ('cut', 0.033816425120772944),
#    ('house', 0.028985507246376812),
#    ('send', 0.026570048309178744),
#    ('happen', 0.024154589371980676),
#    ('josh', 0.021739130434782608),
#    ('real', 0.01932367149758454),
#    ('chat', 0.01932367149758454)]),
#  (4,
#   [('towel', 0.06633906633906633),
#    ('tea', 0.056511056511056514),
#    ('bed', 0.056511056511056514),
#    ('guy', 0.044226044226044224),
#    ('start', 0.044226044226044224),
#    ('chuck', 0.02702702702702703),
#    ('hear', 0.022113022113022112),
#    ('play', 0.019656019656019656),
#    ('food', 0.019656019656019656),
#    ('mr', 0.019656019656019656)]),
#  (5,
#   [('josh', 0.10321100917431193),
#    ('problem', 0.05045871559633028),
#    ('find', 0.034403669724770644),
#    ('write', 0.022935779816513763),
#    ('break', 0.020642201834862386),
#    ('child', 0.01834862385321101),
#    ('wear', 0.013761467889908258),
#    ('idea', 0.013761467889908258),
#    ('question', 0.013761467889908258),
#    ('close', 0.013761467889908258)]),
#  (6,
#   [('thing', 0.12771084337349398),
#    ('big', 0.08674698795180723),
#    ('great', 0.05060240963855422),
#    ('prize', 0.04096385542168675),
#    ('youtube', 0.033734939759036145),
#    ('open', 0.03132530120481928),
#    ('patch', 0.02650602409638554),
#    ('shoe', 0.021686746987951807),
#    ('remember', 0.01927710843373494),
#    ('sleep', 0.014457831325301205)]),
#  (7,
#   [('bit', 0.06451612903225806),
#    ('stuff', 0.05707196029776675),
#    ('music', 0.04714640198511166),
#    ('live', 0.04218362282878412),
#    ('clean', 0.03722084367245657),
#    ('dry', 0.03722084367245657),
#    ('leave', 0.03225806451612903),
#    ('lot', 0.02977667493796526),
#    ('dish', 0.02977667493796526),
#    ('wet', 0.02481389578163772)])]

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=id2word)
vis
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1     -0.116465 -0.033593       1        1  22.241930
# 2      0.063937 -0.119835       2        1  21.189773
# 4      0.041522  0.017073       3        1  20.928838
# 3     -0.058868  0.050387       4        1  19.371146
# 0      0.069873  0.085967       5        1  16.268313, topic_info=          Term       Freq      Total Category  logprob  loglift
# 8           go  98.000000  98.000000  Default  30.0000  30.0000
# 1         good  42.000000  42.000000  Default  29.0000  29.0000
# 80        know  65.000000  65.000000  Default  28.0000  28.0000
# 212      think  66.000000  66.000000  Default  27.0000  27.0000
# 4    christian  31.000000  31.000000  Default  26.0000  26.0000
# ..         ...        ...        ...      ...      ...      ...
# 68       thing   4.170807  42.071722   Topic5  -5.1014  -0.4953
# 14       start   3.348845  14.846310   Topic5  -5.3209   0.3268
# 56         get   4.222480  58.691342   Topic5  -5.0891  -0.8159
# 2          see   3.360832  16.263716   Topic5  -5.3173   0.2392
# 16        josh   3.372600  42.774995   Topic5  -5.3138  -0.7243
#
# [324 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 538       2  0.867828  accumulate
# 586       5  0.845793     acetate
# 145       5  0.637118         age
# 191       5  0.637101       agent
# 766       2  0.867834        aids
# ...     ...       ...         ...
# 219       1  0.515862     youtube
# 219       2  0.085977     youtube
# 219       3  0.171954     youtube
# 219       4  0.085977     youtube
# 219       5  0.171954     youtube
#
# [548 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 3, 5, 4, 1])

# %% [markdown]
# ## Eval

# %%
# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Coherence Score:  0.7310083046492402

# %%
# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2020-08-11 21:52:46,197 : INFO : using ParallelWordOccurrenceAccumulator(processes=7, batch_size=64) to estimate probabilities from sliding windows
# 2020-08-11 21:52:50,121 : INFO : 7 accumulators retrieved from output queue
# 2020-08-11 21:52:50,144 : INFO : accumulated word occurrence stats for 1122 virtual documents
# Coherence Score:  0.683825871706293

# %% [markdown]
# ## Topic Distances

# %%
from gensim.matutils import jensen_shannon
from sklearn.metrics import pairwise_distances


def create_topic_distances(mod, metric=jensen_shannon):
    """Topic distances.

    Inter-topic distance defined as the Jensen-Shannon distance between their
    :math:`p(word | topic)` distributions.

    Parameters
    ------------
    mod: :class:`gensim.models.LdaModel`
        Fitted LDA model
    corpus: list
        Corpus in the same input format as required by
        :class:`gensim.models.LdaModel`.

    Returns
    ---------
    :class:`pandas.DataFrame`
        Data frame with the following columns.

        :doc_id: ``str``. Document string.
        :word: ``str``. Word
        :topic: ``int``. Topic number


    """
    dists = pd.DataFrame(
        pairwise_distances(mod.expElogbeta, metric=metric))
    dists.index.rename("topic_1", inplace=True)
    dists.reset_index(inplace=True)
    dists = dists.melt(
        id_vars=["topic_1"], var_name="topic_2", value_name="distance")
    dists = dists[dists['topic_1'] < dists['topic_2']].copy()
    return dists.sort_values(["topic_1", "topic_2"])
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
create_topic_distances(lda_model, metric=jensen_shannon)
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     topic_1 topic_2  distance
# 7         0       1  0.647586
# 14        0       2  0.647871
# 21        0       3  0.609532
# 28        0       4  0.606980
# 35        0       5  0.623256
# 42        0       6  0.611755
# 15        1       2  0.616435
# 22        1       3  0.554542
# 29        1       4  0.568290
# 36        1       5  0.614577
# 43        1       6  0.540710
# 23        2       3  0.642233
# 30        2       4  0.625955
# 37        2       5  0.602506
# 44        2       6  0.632949
# 31        3       4  0.606649
# 38        3       5  0.628655
# 45        3       6  0.564693
# 39        4       5  0.598661
# 46        4       6  0.521732
# 47        5       6  0.622152

# %% [markdown]
# ## Summarisation

# %% [markdown]
# * https://radimrehurek.com/gensim/summarization/keywords.html
# * https://radimrehurek.com/gensim/auto_examples/tutorials/run_summarization.html

# %%
from gensim.summarization import keywords

# %%
text = data_lemmatized
text = 'this is the best kitchen remodelling in the universe. the government has done a poor job job handling'

# %%
keywords(text).split('\n')
# Out:
# ['job']

# %% [markdown]
# # Nah

# %%
def dump_corpus(corpus, outdir):
    """Dump the values returned by ``create_bow_corpus``."""
    outfile = os.path.join(outdir, "corpus.json.gz")
    with gzip.open(outfile, "wt") as f:
        json.dump(corpus, f)
# Out:
# c:\users\sally\appdata\local\programs\python\python37\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
dump_corpus(corpus,'C:\\Users\\Sally\\WTP')
